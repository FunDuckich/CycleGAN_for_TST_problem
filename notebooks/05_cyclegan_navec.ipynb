# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
from sklearn.decomposition import PCA
from sklearn.decomposition import IncrementalPCA
import torch.nn.functional as F
import os
import re
import nltk
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
from navec import Navec
import scipy.spatial.distance
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\petro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\petro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
lit_vectors_np = np.load("vectorized_lit.npy")
conv_vectors_np = np.load("vectorized_tg.npy")

# %% [markdown]
# # Первая версия модели и гиперпараметров

# %%
vector_dimension = 400 
batch_size = 64  
learning_rate_generators = 0.0002 
learning_rate_discriminators = 0.0001 
num_epochs = 100  
lambda_cycle = 5 
lambda_identity = 5 
beta1_adam = 0.5 
beta2_adam = 0.999  
val_split_ratio = 0.2  
random_seed = 42  
lstm_hidden_dim_generator = 512 
lstm_num_layers_generator = 1 #
lstm_hidden_dim_discriminator = 256
lstm_num_layers_discriminator = 1 
discriminator_layer_size_hidden = 128  
leaky_relu_negative_slope = 0.2 
num_dataloader_workers = 0  
print_batch_interval = 500 
plot_loss_interval_epochs = 5 
output_dir = model_output_dir = "version_1" 
discriminator_dropout_rate = 0.2 
discriminator_weight_decay = 1e-5 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class Generator(nn.Module):
    def __init__(self, input_dim, output_dim, lstm_hidden_dim=lstm_hidden_dim_generator, num_layers=lstm_num_layers_generator): 
        super(Generator, self).__init__()
        self.lstm = nn.LSTM(input_size=input_dim, hidden_size=lstm_hidden_dim, num_layers=num_layers, batch_first=True)
        self.linear_out = nn.Linear(lstm_hidden_dim, output_dim)

    def forward(self, x):
        x = x.unsqueeze(1)
        lstm_out, _ = self.lstm(x)
        output = self.linear_out(lstm_out[:, -1, :])
        return output


class Discriminator(nn.Module):
    def __init__(self, input_dim, lstm_hidden_dim=lstm_hidden_dim_discriminator, num_layers=lstm_num_layers_discriminator, negative_slope=leaky_relu_negative_slope, layer_size_hidden=discriminator_layer_size_hidden): 
        super(Discriminator, self).__init__()
        self.lstm = nn.LSTM(input_size=input_dim, hidden_size=lstm_hidden_dim, num_layers=num_layers, batch_first=True)
        self.linear_hidden = nn.Linear(lstm_hidden_dim, layer_size_hidden) 
        self.leaky_relu = nn.LeakyReLU(negative_slope)
        self.linear_out = nn.Linear(layer_size_hidden, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = x.unsqueeze(1)
        lstm_out, _ = self.lstm(x)
        hidden_out = self.leaky_relu(self.linear_hidden(lstm_out[:, -1, :])) 
        output = self.linear_out(hidden_out)
        return self.sigmoid(output)

# %%
generator_LitToConv = Generator(vector_dimension, vector_dimension).to(device) 
generator_ConvToLit = Generator(vector_dimension, vector_dimension).to(device) 
discriminator_Literary = Discriminator(vector_dimension).to(device) 
discriminator_Conversational = Discriminator(vector_dimension).to(device)

optimizer_G = optim.Adam(list(generator_LitToConv.parameters()) + list(generator_ConvToLit.parameters()),
                         lr=learning_rate_generators, betas=(beta1_adam, beta2_adam))
optimizer_D_lit = optim.Adam(discriminator_Literary.parameters(), lr=learning_rate_discriminators, betas=(beta1_adam, beta2_adam), weight_decay=discriminator_weight_decay)
optimizer_D_conv = optim.Adam(discriminator_Conversational.parameters(), lr=learning_rate_discriminators, betas=(beta1_adam, beta2_adam), weight_decay=discriminator_weight_decay)

# %% [markdown]
# # Вторая версия модели и гиперпараметров

# %%
vector_dimension = 400 
batch_size = 64  
learning_rate_generators = 0.00025 
learning_rate_discriminators = 0.00005 
num_epochs = 100  
lambda_cycle = 7  
lambda_identity = 2  
beta1_adam = 0.5  
beta2_adam = 0.999  # 
val_split_ratio = 0.2  
random_seed = 42  
lstm_hidden_dim_generator = 256
lstm_num_layers_generator = 2 
lstm_hidden_dim_discriminator = 256 
lstm_num_layers_discriminator = 1 
discriminator_layer_size_hidden = 128  
leaky_relu_negative_slope = 0.2  
num_dataloader_workers = 0  
print_batch_interval = 500 #
plot_loss_interval_epochs = 5
output_dir = model_output_dir = "version_2" 
discriminator_dropout_rate = 0.2
discriminator_weight_decay = 1e-5 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class Generator(nn.Module):
    """Генератор для CycleGAN на основе LSTM."""
    def __init__(self, input_dim, output_dim, lstm_hidden_dim=lstm_hidden_dim_generator, num_layers=lstm_num_layers_generator):
        super(Generator, self).__init__()
        self.lstm = nn.LSTM(input_size=input_dim, hidden_size=lstm_hidden_dim, num_layers=num_layers, batch_first=True)
        self.linear_out = nn.Linear(lstm_hidden_dim, output_dim)

    def forward(self, x):
        x = x.unsqueeze(1)
        lstm_out, _ = self.lstm(x)
        output = self.linear_out(lstm_out[:, -1, :])
        return output


class Discriminator(nn.Module):
    def __init__(self, input_dim, lstm_hidden_dim, num_layers, negative_slope, layer_size_hidden, dropout_rate): 
        super(Discriminator, self).__init__()
        self.lstm = nn.LSTM(input_size=input_dim, hidden_size=lstm_hidden_dim, num_layers=num_layers, batch_first=True)
        self.linear_hidden = nn.Linear(lstm_hidden_dim, layer_size_hidden) 
        self.leaky_relu = nn.LeakyReLU(negative_slope) 
        self.dropout = nn.Dropout(dropout_rate) 
        self.linear_out = nn.Linear(layer_size_hidden, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = x.unsqueeze(1)
        lstm_out, _ = self.lstm(x)
        hidden_out = self.leaky_relu(self.linear_hidden(lstm_out[:, -1, :]))
        hidden_out_dropout = self.dropout(hidden_out) 
        output = self.linear_out(hidden_out_dropout) 
        return self.sigmoid(output)

# %%
generator_LitToConv = Generator(vector_dimension, vector_dimension, lstm_hidden_dim_generator, lstm_num_layers_generator).to(device)
generator_ConvToLit = Generator(vector_dimension, vector_dimension, lstm_hidden_dim_generator, lstm_num_layers_generator).to(device)
discriminator_Literary = Discriminator(vector_dimension, lstm_hidden_dim_discriminator, lstm_num_layers_discriminator, leaky_relu_negative_slope, discriminator_layer_size_hidden, discriminator_dropout_rate).to(device)
discriminator_Conversational = Discriminator(vector_dimension, lstm_hidden_dim_discriminator, lstm_num_layers_discriminator, leaky_relu_negative_slope, discriminator_layer_size_hidden, discriminator_dropout_rate).to(device)

optimizer_G = optim.Adam(list(generator_LitToConv.parameters()) + list(generator_ConvToLit.parameters()),
                         lr=learning_rate_generators, betas=(beta1_adam, beta2_adam))
optimizer_D_lit = optim.Adam(discriminator_Literary.parameters(), lr=learning_rate_discriminators, betas=(beta1_adam, beta2_adam), weight_decay=discriminator_weight_decay)
optimizer_D_conv = optim.Adam(discriminator_Conversational.parameters(), lr=learning_rate_discriminators, betas=(beta1_adam, beta2_adam), weight_decay=discriminator_weight_decay)

# %% [markdown]
# # Третья версия модели и гиперпараметров

# %%
vector_dimension = 400 
batch_size = 64  
learning_rate_generators = 0.00025 
learning_rate_discriminators = 0.00005 
num_epochs = 100  
lambda_cycle = 10 
lambda_identity = 3.5 
beta1_adam = 0.5  
beta2_adam = 0.999 
val_split_ratio = 0.2  
random_seed = 42  
lstm_hidden_dim_generator = 256 
lstm_num_layers_generator = 2 
lstm_hidden_dim_discriminator = 256 
lstm_num_layers_discriminator = 1
discriminator_layer_size_hidden = 128  
leaky_relu_negative_slope = 0.2  
num_dataloader_workers = 0 
print_batch_interval = 500 
plot_loss_interval_epochs = 5 
lambda_cycle_l1 = 0.5    
lambda_cycle_cosine = 0.5   
lambda_identity_l1 = 0.5     
lambda_identity_cosine = 0.5
output_dir = model_output_dir = "version_3"
discriminator_dropout_rate = 0.2 
discriminator_weight_decay = 1e-5 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class Generator(nn.Module):
    """Генератор для CycleGAN на основе LSTM."""
    def __init__(self, input_dim, output_dim, lstm_hidden_dim=lstm_hidden_dim_generator, num_layers=lstm_num_layers_generator):
        super(Generator, self).__init__()
        self.lstm = nn.LSTM(input_size=input_dim, hidden_size=lstm_hidden_dim, num_layers=num_layers, batch_first=True)
        self.linear_out = nn.Linear(lstm_hidden_dim, output_dim)

    def forward(self, x):
        x = x.unsqueeze(1)
        lstm_out, _ = self.lstm(x)
        output = self.linear_out(lstm_out[:, -1, :])
        return output


class Discriminator(nn.Module):
    def __init__(self, input_dim, lstm_hidden_dim, num_layers, negative_slope, layer_size_hidden, dropout_rate): 
        super(Discriminator, self).__init__()
        self.lstm = nn.LSTM(input_size=input_dim, hidden_size=lstm_hidden_dim, num_layers=num_layers, batch_first=True) 
        self.linear_hidden = nn.Linear(lstm_hidden_dim, layer_size_hidden) 
        self.leaky_relu = nn.LeakyReLU(negative_slope) 
        self.dropout = nn.Dropout(dropout_rate) 
        self.linear_out = nn.Linear(layer_size_hidden, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = x.unsqueeze(1)
        lstm_out, _ = self.lstm(x)
        hidden_out = self.leaky_relu(self.linear_hidden(lstm_out[:, -1, :]))
        hidden_out_dropout = self.dropout(hidden_out)
        output = self.linear_out(hidden_out_dropout) 
        return self.sigmoid(output)

# %%
generator_LitToConv = Generator(vector_dimension, vector_dimension, lstm_hidden_dim_generator, lstm_num_layers_generator).to(device)
generator_ConvToLit = Generator(vector_dimension, vector_dimension, lstm_hidden_dim_generator, lstm_num_layers_generator).to(device)
discriminator_Literary = Discriminator(vector_dimension, lstm_hidden_dim_discriminator, lstm_num_layers_discriminator, leaky_relu_negative_slope, discriminator_layer_size_hidden, discriminator_dropout_rate).to(device)
discriminator_Conversational = Discriminator(vector_dimension, lstm_hidden_dim_discriminator, lstm_num_layers_discriminator, leaky_relu_negative_slope, discriminator_layer_size_hidden, discriminator_dropout_rate).to(device)

optimizer_G = optim.Adam(list(generator_LitToConv.parameters()) + list(generator_ConvToLit.parameters()),
                         lr=learning_rate_generators, betas=(beta1_adam, beta2_adam))
optimizer_D_lit = optim.Adam(discriminator_Literary.parameters(), lr=learning_rate_discriminators, betas=(beta1_adam, beta2_adam), weight_decay=discriminator_weight_decay)
optimizer_D_conv = optim.Adam(discriminator_Conversational.parameters(), lr=learning_rate_discriminators, betas=(beta1_adam, beta2_adam), weight_decay=discriminator_weight_decay)

# %% [markdown]
# # Четвёртая версия модели и гиперпараметров

# %%
vector_dimension = 400 
batch_size = 64  
learning_rate_generators = 0.0002 
learning_rate_discriminators = 0.00005 
num_epochs = 100  
lambda_cycle = 4 
lambda_identity = 4 
beta1_adam = 0.5  
beta2_adam = 0.999  
val_split_ratio = 0.2  
random_seed = 42  #
lstm_hidden_dim_generator = 400 
lstm_num_layers_generator = 3 
lstm_hidden_dim_discriminator = 160 
lstm_num_layers_discriminator = 1 
discriminator_layer_size_hidden = 40  
leaky_relu_negative_slope = 0.2 
num_dataloader_workers = 0  
print_batch_interval = 500 
plot_loss_interval_epochs = 5 
lambda_cycle_l1 = 0.5      
lambda_cycle_cosine = 0.5   
lambda_identity_l1 = 0.5   
lambda_identity_cosine = 0.5
output_dir = model_output_dir = "version_4" 
discriminator_dropout_rate = 0.4 
discriminator_weight_decay = 1e-3 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class Generator(nn.Module):
    def __init__(self, input_dim, output_dim, lstm_hidden_dim=lstm_hidden_dim_generator, num_layers=lstm_num_layers_generator): 
        super(Generator, self).__init__()
        self.lstm = nn.LSTM(input_size=input_dim, hidden_size=lstm_hidden_dim, num_layers=num_layers, batch_first=True)
        self.linear_out = nn.Linear(lstm_hidden_dim, output_dim)

    def forward(self, x):
        x = x.unsqueeze(1)
        lstm_out, _ = self.lstm(x)
        output = self.linear_out(lstm_out[:, -1, :])
        return output


class Discriminator(nn.Module):
    def __init__(self, input_dim, lstm_hidden_dim, num_layers, negative_slope, layer_size_hidden, dropout_rate): 
        super(Discriminator, self).__init__()
        self.lstm = nn.LSTM(input_size=input_dim, hidden_size=lstm_hidden_dim, num_layers=num_layers, batch_first=True) 
        self.linear_hidden = nn.Linear(lstm_hidden_dim, layer_size_hidden) 
        self.leaky_relu = nn.LeakyReLU(negative_slope) 
        self.dropout = nn.Dropout(dropout_rate) 
        self.linear_out = nn.Linear(layer_size_hidden, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = x.unsqueeze(1)
        lstm_out, _ = self.lstm(x)
        hidden_out = self.leaky_relu(self.linear_hidden(lstm_out[:, -1, :]))
        hidden_out_dropout = self.dropout(hidden_out) 
        output = self.linear_out(hidden_out_dropout)
        return self.sigmoid(output)

# %%
generator_LitToConv = Generator(vector_dimension, vector_dimension, lstm_hidden_dim_generator, lstm_num_layers_generator).to(device)
generator_ConvToLit = Generator(vector_dimension, vector_dimension, lstm_hidden_dim_generator, lstm_num_layers_generator).to(device)
discriminator_Literary = Discriminator(vector_dimension, lstm_hidden_dim_discriminator, lstm_num_layers_discriminator, leaky_relu_negative_slope, discriminator_layer_size_hidden, discriminator_dropout_rate).to(device)
discriminator_Conversational = Discriminator(vector_dimension, lstm_hidden_dim_discriminator, lstm_num_layers_discriminator, leaky_relu_negative_slope, discriminator_layer_size_hidden, discriminator_dropout_rate).to(device)

optimizer_G = optim.Adam(list(generator_LitToConv.parameters()) + list(generator_ConvToLit.parameters()),
                         lr=learning_rate_generators, betas=(beta1_adam, beta2_adam))
optimizer_D_lit = optim.Adam(discriminator_Literary.parameters(), lr=learning_rate_discriminators, betas=(beta1_adam, beta2_adam), weight_decay=discriminator_weight_decay)
optimizer_D_conv = optim.Adam(discriminator_Conversational.parameters(), lr=learning_rate_discriminators, betas=(beta1_adam, beta2_adam), weight_decay=discriminator_weight_decay)

# %% [markdown]
# # Ф-ции сохранения моделей и графиков

# %%
def plot_losses(history, epoch, output_dir=output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    epochs_range = range(1, epoch + 1)

    print("Debugging plot_losses:")
    print(f"Length epochs_range: {len(epochs_range)}")
    for key, value in history.items():
        print(f"Length history['{key}']: {len(value)}")


    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    sns.lineplot(x=epochs_range, y=history['D_lit_train'], label='D_lit_train')
    sns.lineplot(x=epochs_range, y=history['D_lit_val'], label='D_lit_val')
    plt.title('Loss дискриминатора литературного стиля')
    plt.xlabel('Эпоха')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    sns.lineplot(x=epochs_range, y=history['D_conv_train'], label='D_conv_train')
    sns.lineplot(x=epochs_range, y=history['D_conv_val'], label='D_conv_val')
    plt.title('Loss дискриминатора разговорного стиля')
    plt.xlabel('Эпоха')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, f'discriminators_losses.png'))
    plt.close()

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    sns.lineplot(x=epochs_range, y=history['G_train'], label='G_train')
    sns.lineplot(x=epochs_range, y=history['G_val'], label='G_val')
    plt.title('Loss генераторов')
    plt.xlabel('Эпоха')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    sns.lineplot(x=epochs_range, y=history['cycle_train'], label='Cycle_train')
    sns.lineplot(x=epochs_range, y=history['cycle_val'], label='Cycle_val')
    plt.title('Cycle Consistency Loss')
    plt.xlabel('Эпоха')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, f'generators_and_cycle_losses.png'))
    plt.close()

    plt.figure(figsize=(6, 5))
    sns.lineplot(x=epochs_range, y=history['identity_train'], label='Identity_train')
    sns.lineplot(x=epochs_range, y=history['identity_val'], label='Identity_val')
    plt.title('Identity Loss')
    plt.xlabel('Эпоха')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, f'identity_losses.png'))
    plt.close()


def save_models(epoch, generator_lit_to_conv, generator_conv_to_lit, discriminator_literary, discriminator_conversational, optimizer_g, optimizer_d_lit, optimizer_d_conv, output_dir=model_output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    torch.save(generator_lit_to_conv.state_dict(), os.path.join(output_dir, f'generator_lit_to_conv.pth')) 
    torch.save(generator_conv_to_lit.state_dict(), os.path.join(output_dir, f'generator_conv_to_lit.pth')) 
    torch.save(discriminator_literary.state_dict(), os.path.join(output_dir, f'discriminator_literary.pth')) 
    torch.save(discriminator_conversational.state_dict(), os.path.join(output_dir, f'discriminator_conversational.pth')) 
    torch.save(optimizer_g.state_dict(), os.path.join(output_dir, f'optimizer_g.pth')) 
    torch.save(optimizer_d_lit.state_dict(), os.path.join(output_dir, f'optimizer_d_lit.pth')) 
    torch.save(optimizer_d_conv.state_dict(), os.path.join(output_dir, f'optimizer_d_conv.pth')) 
    print(f"Модели перезаписаны в {output_dir} на {epoch} эпохе")

# %% [markdown]
# # Общая подготовка к обучению

# %%
class SentenceDataset(torch.utils.data.Dataset):
    def __init__(self, literary_vectors, conversational_vectors):
        self.literary_data = torch.tensor(literary_vectors, dtype=torch.float32)
        self.conversational_data = torch.tensor(conversational_vectors, dtype=torch.float32)
        self.dataset_len = len(self.literary_data) 

    def __len__(self):
        return self.dataset_len 

    def __getitem__(self, idx):
        return self.literary_data[idx], self.conversational_data[idx]

# %%
lit_train, lit_val, conv_train, conv_val = train_test_split(
    lit_vectors_np, conv_vectors_np, test_size=val_split_ratio, random_state=random_seed
)

# %%
train_dataset = SentenceDataset(lit_train, conv_train)
val_dataset = SentenceDataset(lit_val, conv_val)

# %%
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_dataloader_workers)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_dataloader_workers)

# %%
history = {'D_lit_train': [], 'D_conv_train': [], 'G_train': [], 'cycle_train': [], 'identity_train': [],
           'D_lit_val': [], 'D_conv_val': [], 'G_val': [], 'cycle_val': [], 'identity_val': []}

# %% [markdown]
# # Подготовка и обучение для 1 и 2 версий

# %%
criterion_GAN = nn.BCELoss()
criterion_cycle = nn.L1Loss()
criterion_identity = nn.L1Loss()

# %%
for epoch in range(num_epochs):
    generator_LitToConv.train()
    generator_ConvToLit.train()
    discriminator_Literary.train()
    discriminator_Conversational.train()

    train_loss_D_lit_accum = 0.0
    train_loss_D_conv_accum = 0.0
    train_loss_G_accum = 0.0
    train_loss_cycle_accum = 0.0
    train_loss_identity_accum = 0.0
    num_train_batches = 0

    for i, (real_literary, real_conversational) in enumerate(train_dataloader):
        real_literary = real_literary.to(device)
        real_conversational = real_conversational.to(device)

        valid = torch.ones(real_literary.size(0), 1).to(device)
        fake = torch.zeros(real_literary.size(0), 1).to(device)

        optimizer_D_lit.zero_grad()
        optimizer_D_conv.zero_grad()

        loss_D_lit_real = criterion_GAN(discriminator_Literary(real_literary), valid)
        fake_literary = generator_ConvToLit(real_conversational)
        loss_D_lit_fake = criterion_GAN(discriminator_Literary(fake_literary.detach()), fake)
        loss_D_lit = (loss_D_lit_real + loss_D_lit_fake) / 2
        loss_D_lit.backward()
        optimizer_D_lit.step()

        loss_D_conv_real = criterion_GAN(discriminator_Conversational(real_conversational), valid)
        fake_conversational = generator_LitToConv(real_literary)
        loss_D_conv_fake = criterion_GAN(discriminator_Conversational(fake_conversational.detach()), fake)
        loss_D_conv = (loss_D_conv_real + loss_D_conv_fake) / 2
        loss_D_conv.backward()
        optimizer_D_conv.step()

        optimizer_G.zero_grad()

        fake_conversational = generator_LitToConv(real_literary)
        loss_GAN_LitToConv = criterion_GAN(discriminator_Conversational(fake_conversational), valid)

        fake_literary = generator_ConvToLit(real_conversational)
        loss_GAN_ConvToLit = criterion_GAN(discriminator_Literary(fake_literary), valid)

        recovered_literary = generator_ConvToLit(fake_conversational)
        loss_cycle_lit = criterion_cycle(recovered_literary, real_literary)

        recovered_conversational = generator_LitToConv(fake_literary)
        loss_cycle_conv = criterion_cycle(recovered_conversational, real_conversational)

        loss_cycle = (loss_cycle_lit + loss_cycle_conv) / 2

        identity_conversational = generator_LitToConv(real_conversational)
        loss_identity_conv = criterion_identity(identity_conversational, real_conversational)

        identity_literary = generator_ConvToLit(real_literary)
        loss_identity_lit = criterion_identity(identity_literary, real_literary)

        loss_identity = (loss_identity_conv + loss_identity_lit) / 2

        loss_G =  (loss_GAN_LitToConv + loss_GAN_ConvToLit) + \
                  lambda_cycle * loss_cycle + \
                  lambda_identity * loss_identity
        loss_G.backward()
        optimizer_G.step()

        train_loss_D_lit_accum += loss_D_lit.item()
        train_loss_D_conv_accum += loss_D_conv.item()
        train_loss_G_accum += loss_G.item()
        train_loss_cycle_accum += loss_cycle.item()
        train_loss_identity_accum += loss_identity.item()
        num_train_batches += 1

        if i % print_batch_interval == 0:
            print(f"Эпоха [{epoch + 1}/{num_epochs}] Батч [{i}/{len(train_dataloader)}] "
                  f"D_lit_loss: {loss_D_lit.item():.4f} D_conv_loss: {loss_D_conv.item():.4f} "
                  f"G_loss: {loss_G.item():.4f}")

    generator_LitToConv.eval()
    generator_ConvToLit.eval()
    discriminator_Literary.eval()
    discriminator_Conversational.eval()

    val_loss_D_lit_accum = 0.0
    val_loss_D_conv_accum = 0.0
    val_loss_G_accum = 0.0
    val_loss_cycle_accum = 0.0
    val_loss_identity_accum = 0.0
    num_val_batches = 0

    with torch.no_grad():
        for i_val, (val_literary, val_conversational) in enumerate(val_dataloader):
            val_literary = val_literary.to(device)
            val_conversational = val_conversational.to(device)
            val_valid = torch.ones(val_literary.size(0), 1).to(device)
            val_fake = torch.zeros(val_literary.size(0), 1).to(device)

            val_loss_D_lit_real = criterion_GAN(discriminator_Literary(val_literary), val_valid)
            val_fake_literary = generator_ConvToLit(val_conversational)
            val_loss_D_lit_fake = criterion_GAN(discriminator_Literary(val_fake_literary), val_fake)
            val_loss_D_lit_val = (val_loss_D_lit_real + val_loss_D_lit_fake) / 2

            val_loss_D_conv_real = criterion_GAN(discriminator_Conversational(val_conversational), val_valid)
            val_fake_conversational = generator_LitToConv(val_literary)
            val_loss_D_conv_fake = criterion_GAN(discriminator_Conversational(val_fake_conversational), val_fake)
            val_loss_D_conv_val = (val_loss_D_conv_real + val_loss_D_conv_fake) / 2

            val_loss_GAN_LitToConv = criterion_GAN(discriminator_Conversational(val_fake_conversational), val_valid)
            val_loss_GAN_ConvToLit = criterion_GAN(discriminator_Literary(val_fake_literary), val_valid)

            val_recovered_literary = generator_ConvToLit(val_fake_conversational)
            val_loss_cycle_lit = criterion_cycle(val_recovered_literary, val_literary)
            val_recovered_conversational = generator_LitToConv(val_fake_literary)
            val_loss_cycle_conv = criterion_cycle(val_recovered_conversational, val_conversational)
            val_loss_cycle_val = (val_loss_cycle_lit + val_loss_cycle_conv) / 2

            val_identity_conversational = generator_LitToConv(val_conversational)
            val_loss_identity_conv = criterion_identity(val_identity_conversational, val_conversational)
            val_identity_literary = generator_ConvToLit(val_literary)
            val_loss_identity_lit = criterion_identity(val_identity_literary, val_literary)
            val_loss_identity_val = (val_loss_identity_conv + val_loss_identity_lit) / 2

            val_loss_G_val = (val_loss_GAN_LitToConv + val_loss_GAN_ConvToLit) + \
                            lambda_cycle * val_loss_cycle_val + \
                            lambda_identity * val_loss_identity_val

            val_loss_D_lit_accum += val_loss_D_lit_val.item()
            val_loss_D_conv_accum += val_loss_D_conv_val.item()
            val_loss_G_accum += val_loss_G_val.item()
            val_loss_cycle_accum += val_loss_cycle_val.item()
            val_loss_identity_accum += val_loss_identity_val.item()
            num_val_batches += 1

    avg_val_loss_D_lit = val_loss_D_lit_accum / num_val_batches
    avg_val_loss_D_conv = val_loss_D_conv_accum / num_val_batches
    avg_val_loss_G = val_loss_G_accum / num_val_batches
    avg_val_loss_cycle = val_loss_cycle_accum / num_val_batches
    avg_val_loss_identity = val_loss_identity_accum / num_val_batches

    generator_LitToConv.train()
    generator_ConvToLit.train()
    discriminator_Literary.train()
    discriminator_Conversational.train()

    history['D_lit_train'].append(train_loss_D_lit_accum / num_train_batches)
    history['D_conv_train'].append(train_loss_D_conv_accum / num_train_batches)
    history['G_train'].append(train_loss_G_accum / num_train_batches)
    history['cycle_train'].append(train_loss_cycle_accum / num_train_batches)
    history['identity_train'].append(train_loss_identity_accum / num_train_batches)

    history['D_lit_val'].append(avg_val_loss_D_lit)
    history['D_conv_val'].append(avg_val_loss_D_conv)
    history['G_val'].append(avg_val_loss_G)
    history['cycle_val'].append(avg_val_loss_cycle)
    history['identity_val'].append(avg_val_loss_identity)

    print(f"Эпоха [{epoch + 1}/{num_epochs}] Обучение--- "
          f"D_lit_loss: {history['D_lit_train'][-1]:.4f} D_conv_loss: {history['D_conv_train'][-1]:.4f} "
          f"G_loss: {history['G_train'][-1]:.4f} cycle_loss: {history['cycle_train'][-1]:.4f} identity_loss: {history['identity_train'][-1]:.4f}")
    print(f"Эпоха [{epoch + 1}/{num_epochs}] Валидация --- "
          f"Val_D_lit_loss: {history['D_lit_val'][-1]:.4f} Val_D_conv_loss: {history['D_conv_val'][-1]:.4f} "
          f"Val_G_loss: {history['G_val'][-1]:.4f} Val_cycle_loss: {history['cycle_val'][-1]:.4f} Val_identity_loss: {history['identity_val'][-1]:.4f}")

    save_models(epoch + 1, generator_LitToConv, generator_ConvToLit, discriminator_Literary, discriminator_Conversational, optimizer_G, optimizer_D_lit, optimizer_D_conv)
    plot_losses(history, epoch + 1)

print("Обучение завершено!")

plot_losses(history, num_epochs)

# %% [markdown]
# # Подготовка и обучение для 3 и 4 версий

# %%
def cosine_distance_loss(output, target):
    cosine_similarity = F.cosine_similarity(output, target)
    cosine_distance = (1 - cosine_similarity) / 2
    loss = torch.mean(cosine_distance)
    return loss

# %%
criterion_GAN = nn.BCELoss()
criterion_cycle_l1 = nn.L1Loss() 
criterion_cycle_cosine = cosine_distance_loss 
criterion_identity_l1 = nn.L1Loss() 
criterion_identity_cosine = cosine_distance_loss

# %%
for epoch in range(num_epochs):
    generator_LitToConv.train()
    generator_ConvToLit.train()
    discriminator_Literary.train()
    discriminator_Conversational.train()

    train_loss_D_lit_accum = 0.0
    train_loss_D_conv_accum = 0.0
    train_loss_G_accum = 0.0
    train_loss_cycle_accum = 0.0
    train_loss_identity_accum = 0.0
    num_train_batches = 0

    for i, (real_literary, real_conversational) in enumerate(train_dataloader):
        real_literary = real_literary.to(device)
        real_conversational = real_conversational.to(device)

        valid = torch.ones(real_literary.size(0), 1).to(device)
        fake = torch.zeros(real_literary.size(0), 1).to(device)

        optimizer_D_lit.zero_grad()
        optimizer_D_conv.zero_grad()

        loss_D_lit_real = criterion_GAN(discriminator_Literary(real_literary), valid)
        fake_literary = generator_ConvToLit(real_conversational)
        loss_D_lit_fake = criterion_GAN(discriminator_Literary(fake_literary.detach()), fake)
        loss_D_lit = (loss_D_lit_real + loss_D_lit_fake) / 2
        loss_D_lit.backward()
        optimizer_D_lit.step()

        loss_D_conv_real = criterion_GAN(discriminator_Conversational(real_conversational), valid)
        fake_conversational = generator_LitToConv(real_literary)
        loss_D_conv_fake = criterion_GAN(discriminator_Conversational(fake_conversational.detach()), fake)
        loss_D_conv = (loss_D_conv_real + loss_D_conv_fake) / 2
        loss_D_conv.backward()
        optimizer_D_conv.step()

        optimizer_G.zero_grad()

        # GAN Loss
        fake_conversational = generator_LitToConv(real_literary)
        loss_GAN_LitToConv = criterion_GAN(discriminator_Conversational(fake_conversational), valid)

        fake_literary = generator_ConvToLit(real_conversational)
        loss_GAN_ConvToLit = criterion_GAN(discriminator_Literary(fake_literary), valid)

        recovered_literary = generator_ConvToLit(fake_conversational)
        loss_cycle_lit_l1 = criterion_cycle_l1(recovered_literary, real_literary)
        loss_cycle_lit_cosine = criterion_cycle_cosine(recovered_literary, real_literary)
        loss_cycle_lit = lambda_cycle_l1 * loss_cycle_lit_l1 + lambda_cycle_cosine * loss_cycle_lit_cosine

        recovered_conversational = generator_LitToConv(fake_literary)
        loss_cycle_conv_l1 = criterion_cycle_l1(recovered_conversational, real_conversational)
        loss_cycle_conv_cosine = criterion_cycle_cosine(recovered_conversational, real_conversational)
        loss_cycle_conv = lambda_cycle_l1 * loss_cycle_conv_l1 + lambda_cycle_cosine * loss_cycle_conv_cosine

        loss_cycle = (loss_cycle_lit + loss_cycle_conv) / 2

        identity_conversational = generator_LitToConv(real_conversational)
        loss_identity_conv_l1 = criterion_identity_l1(identity_conversational, real_conversational)
        loss_identity_conv_cosine = criterion_identity_cosine(identity_conversational, real_conversational)
        loss_identity_conv = lambda_identity_l1 * loss_identity_conv_l1 + lambda_identity_cosine * loss_identity_conv_cosine

        identity_literary = generator_ConvToLit(real_literary)
        loss_identity_lit_l1 = criterion_identity_l1(identity_literary, real_literary)
        loss_identity_lit_cosine = criterion_identity_cosine(identity_literary, real_literary)
        loss_identity_lit = lambda_identity_l1 * loss_identity_lit_l1 + lambda_identity_cosine * loss_identity_lit_cosine

        loss_identity = (loss_identity_conv + loss_identity_lit) / 2

        loss_G =  (loss_GAN_LitToConv + loss_GAN_ConvToLit) + \
                  lambda_cycle * loss_cycle + \
                  lambda_identity * loss_identity
        loss_G.backward()
        optimizer_G.step()

        train_loss_D_lit_accum += loss_D_lit.item()
        train_loss_D_conv_accum += loss_D_conv.item()
        train_loss_G_accum += loss_G.item()
        train_loss_cycle_accum += loss_cycle.item()
        train_loss_identity_accum += loss_identity.item()
        num_train_batches += 1

        if i % print_batch_interval == 0:
            print(f"Эпоха [{epoch + 1}/{num_epochs}] Батч [{i}/{len(train_dataloader)}] "
                  f"D_lit_loss: {loss_D_lit.item():.4f} D_conv_loss: {loss_D_conv.item():.4f} "
                  f"G_loss: {loss_G.item():.4f}")

    generator_LitToConv.eval()
    generator_ConvToLit.eval()
    discriminator_Literary.eval()
    discriminator_Conversational.eval()

    val_loss_D_lit_accum = 0.0
    val_loss_D_conv_accum = 0.0
    val_loss_G_accum = 0.0
    val_loss_cycle_accum = 0.0
    val_loss_identity_accum = 0.0
    num_val_batches = 0

    with torch.no_grad():
        for i_val, (val_literary, val_conversational) in enumerate(val_dataloader):
            val_literary = val_literary.to(device)
            val_conversational = val_conversational.to(device)
            val_valid = torch.ones(val_literary.size(0), 1).to(device)
            val_fake = torch.zeros(val_literary.size(0), 1).to(device)

            val_loss_D_lit_real = criterion_GAN(discriminator_Literary(val_literary), val_valid)
            val_fake_literary = generator_ConvToLit(val_conversational)
            val_loss_D_lit_fake = criterion_GAN(discriminator_Literary(val_fake_literary), val_fake)
            val_loss_D_lit_val = (val_loss_D_lit_real + val_loss_D_lit_fake) / 2

            val_loss_D_conv_real = criterion_GAN(discriminator_Conversational(val_conversational), val_valid)
            val_fake_conversational = generator_LitToConv(val_literary)
            val_loss_D_conv_fake = criterion_GAN(discriminator_Conversational(val_fake_conversational), val_fake)
            val_loss_D_conv_val = (val_loss_D_conv_real + val_loss_D_conv_fake) / 2

            val_loss_GAN_LitToConv = criterion_GAN(discriminator_Conversational(val_fake_conversational), val_valid)
            val_loss_GAN_ConvToLit = criterion_GAN(discriminator_Literary(val_fake_literary), val_valid)

            val_fake_conversational = generator_LitToConv(val_literary)
            val_fake_literary = generator_ConvToLit(val_conversational)

            val_recovered_literary = generator_ConvToLit(val_fake_conversational)
            val_recovered_conversational = generator_LitToConv(val_fake_literary)

            val_loss_cycle_lit_l1 = criterion_cycle_l1(val_recovered_literary, val_literary)
            val_loss_cycle_lit_cosine = criterion_cycle_cosine(val_recovered_literary, val_literary)
            val_loss_cycle_lit_val = lambda_cycle_l1 * val_loss_cycle_lit_l1 + lambda_cycle_cosine * val_loss_cycle_lit_cosine

            val_loss_cycle_conv_l1 = criterion_cycle_l1(val_recovered_conversational, val_conversational)
            val_loss_cycle_conv_cosine = criterion_cycle_cosine(val_recovered_conversational, val_conversational)
            val_loss_cycle_conv_val = lambda_cycle_l1 * val_loss_cycle_conv_l1 + lambda_cycle_cosine * val_loss_cycle_conv_cosine

            val_loss_cycle_val = (val_loss_cycle_lit_val + val_loss_cycle_conv_val) / 2

            val_identity_conversational = generator_LitToConv(val_conversational)
            val_identity_literary = generator_ConvToLit(val_literary) 

            val_loss_identity_conv_l1 = criterion_identity_l1(val_identity_conversational, val_conversational)
            val_loss_identity_conv_cosine = criterion_identity_cosine(val_identity_conversational, val_conversational)
            val_loss_identity_conv_val = lambda_identity_l1 * val_loss_identity_conv_l1 + lambda_identity_cosine * val_loss_identity_conv_cosine

            val_loss_identity_lit_l1 = criterion_identity_l1(val_identity_literary, val_literary)
            val_loss_identity_lit_cosine = criterion_identity_cosine(val_identity_literary, val_literary)
            val_loss_identity_lit_val = lambda_identity_l1 * val_loss_identity_lit_l1 + lambda_identity_cosine * val_loss_identity_lit_cosine

            val_loss_identity_val = (val_loss_identity_conv_val + val_loss_identity_lit_val) / 2 

            val_loss_G_val = (val_loss_GAN_LitToConv + val_loss_GAN_ConvToLit) + \
                            lambda_cycle * val_loss_cycle_val + \
                            lambda_identity * val_loss_identity_val

            val_loss_D_lit_accum += val_loss_D_lit_val.item()
            val_loss_D_conv_accum += val_loss_D_conv_val.item()
            val_loss_G_accum += val_loss_G_val.item()
            val_loss_cycle_accum += val_loss_cycle_val.item()
            val_loss_identity_accum += val_loss_identity_val.item()
            num_val_batches += 1

    avg_val_loss_D_lit = val_loss_D_lit_accum / num_val_batches
    avg_val_loss_D_conv = val_loss_D_conv_accum / num_val_batches
    avg_val_loss_G = val_loss_G_accum / num_val_batches
    avg_val_loss_cycle = val_loss_cycle_accum / num_val_batches
    avg_val_loss_identity = val_loss_identity_accum / num_val_batches

    generator_LitToConv.train()
    generator_ConvToLit.train()
    discriminator_Literary.train()
    discriminator_Conversational.train()

    # Сохранение и печать loss-ов для каждой эпохи
    history['D_lit_train'].append(train_loss_D_lit_accum / num_train_batches)
    history['D_conv_train'].append(train_loss_D_conv_accum / num_train_batches)
    history['G_train'].append(train_loss_G_accum / num_train_batches)
    history['cycle_train'].append(train_loss_cycle_accum / num_train_batches)
    history['identity_train'].append(train_loss_identity_accum / num_train_batches)

    history['D_lit_val'].append(avg_val_loss_D_lit)
    history['D_conv_val'].append(avg_val_loss_D_conv)
    history['G_val'].append(avg_val_loss_G)
    history['cycle_val'].append(avg_val_loss_cycle)
    history['identity_val'].append(avg_val_loss_identity)

    print(f"Эпоха [{epoch + 1}/{num_epochs}] Обучение--- "
          f"D_lit_loss: {history['D_lit_train'][-1]:.4f} D_conv_loss: {history['D_conv_train'][-1]:.4f} "
          f"G_loss: {history['G_train'][-1]:.4f} cycle_loss: {history['cycle_train'][-1]:.4f} identity_loss: {history['identity_train'][-1]:.4f}")
    print(f"Эпоха [{epoch + 1}/{num_epochs}] Валидация --- "
          f"Val_D_lit_loss: {history['D_lit_val'][-1]:.4f} Val_D_conv_loss: {history['D_conv_val'][-1]:.4f} "
          f"Val_G_loss: {history['G_val'][-1]:.4f} Val_cycle_loss: {history['cycle_val'][-1]:.4f} Val_identity_loss: {history['identity_val'][-1]:.4f}")

    if (epoch + 1) % plot_loss_interval_epochs == 0:
        plot_losses(history, epoch + 1)

    save_models(epoch + 1, generator_LitToConv, generator_ConvToLit, discriminator_Literary, discriminator_Conversational, optimizer_G, optimizer_D_lit, optimizer_D_conv)


print("Обучение завершено!")
# Out:
# Эпоха [1/100] Батч [0/17229] D_lit_loss: 0.6966 D_conv_loss: 0.6978 G_loss: 4.2750
# Эпоха [1/100] Батч [500/17229] D_lit_loss: 0.6845 D_conv_loss: 0.6897 G_loss: 2.3325
# Эпоха [1/100] Батч [1000/17229] D_lit_loss: 0.6862 D_conv_loss: 0.6944 G_loss: 2.1245
# Эпоха [1/100] Батч [1500/17229] D_lit_loss: 0.6918 D_conv_loss: 0.6914 G_loss: 2.0802
# Эпоха [1/100] Батч [2000/17229] D_lit_loss: 0.7088 D_conv_loss: 0.6886 G_loss: 1.9754
# Эпоха [1/100] Батч [2500/17229] D_lit_loss: 0.6810 D_conv_loss: 0.6826 G_loss: 2.0314
# Эпоха [1/100] Батч [3000/17229] D_lit_loss: 0.6884 D_conv_loss: 0.6829 G_loss: 1.9735
# Эпоха [1/100] Батч [3500/17229] D_lit_loss: 0.6950 D_conv_loss: 0.6933 G_loss: 1.9470
# Эпоха [1/100] Батч [4000/17229] D_lit_loss: 0.6943 D_conv_loss: 0.6894 G_loss: 1.8855
# Эпоха [1/100] Батч [4500/17229] D_lit_loss: 0.6888 D_conv_loss: 0.6882 G_loss: 1.8435
# Эпоха [1/100] Батч [5000/17229] D_lit_loss: 0.6891 D_conv_loss: 0.6828 G_loss: 1.8170
# Эпоха [1/100] Батч [5500/17229] D_lit_loss: 0.6982 D_conv_loss: 0.6926 G_loss: 1.8113
# Эпоха [1/100] Батч [6000/17229] D_lit_loss: 0.6871 D_conv_loss: 0.6902 G_loss: 1.7997
# Эпоха [1/100] Батч [6500/17229] D_lit_loss: 0.6890 D_conv_loss: 0.6911 G_loss: 1.8778
# Эпоха [1/100] Батч [7000/17229] D_lit_loss: 0.7020 D_conv_loss: 0.6872 G_loss: 1.7273
# Эпоха [1/100] Батч [7500/17229] D_lit_loss: 0.6865 D_conv_loss: 0.6894 G_loss: 1.7494
# Эпоха [1/100] Батч [8000/17229] D_lit_loss: 0.6920 D_conv_loss: 0.6892 G_loss: 1.7405
# Эпоха [1/100] Батч [8500/17229] D_lit_loss: 0.6907 D_conv_loss: 0.6863 G_loss: 1.6916
# Эпоха [1/100] Батч [9000/17229] D_lit_loss: 0.6941 D_conv_loss: 0.6925 G_loss: 1.7183
# Эпоха [1/100] Батч [9500/17229] D_lit_loss: 0.6902 D_conv_loss: 0.6871 G_loss: 1.6952
# Эпоха [1/100] Батч [10000/17229] D_lit_loss: 0.7012 D_conv_loss: 0.6938 G_loss: 1.6925
# Эпоха [1/100] Батч [10500/17229] D_lit_loss: 0.6875 D_conv_loss: 0.6924 G_loss: 1.6792
# Эпоха [1/100] Батч [11000/17229] D_lit_loss: 0.6883 D_conv_loss: 0.6925 G_loss: 1.7094
# Эпоха [1/100] Батч [11500/17229] D_lit_loss: 0.6859 D_conv_loss: 0.6822 G_loss: 1.6694
# Эпоха [1/100] Батч [12000/17229] D_lit_loss: 0.6902 D_conv_loss: 0.6924 G_loss: 1.6774
# Эпоха [1/100] Батч [12500/17229] D_lit_loss: 0.6949 D_conv_loss: 0.6864 G_loss: 1.6565
# Эпоха [1/100] Батч [13000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6936 G_loss: 1.7364
# Эпоха [1/100] Батч [13500/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6904 G_loss: 1.6034
# Эпоха [1/100] Батч [14000/17229] D_lit_loss: 0.6846 D_conv_loss: 0.6899 G_loss: 1.7057
# Эпоха [1/100] Батч [14500/17229] D_lit_loss: 0.6965 D_conv_loss: 0.6924 G_loss: 1.6195
# Эпоха [1/100] Батч [15000/17229] D_lit_loss: 0.6927 D_conv_loss: 0.6916 G_loss: 1.6659
# Эпоха [1/100] Батч [15500/17229] D_lit_loss: 0.6925 D_conv_loss: 0.6921 G_loss: 1.5980
# Эпоха [1/100] Батч [16000/17229] D_lit_loss: 0.6914 D_conv_loss: 0.6885 G_loss: 1.6186
# Эпоха [1/100] Батч [16500/17229] D_lit_loss: 0.6990 D_conv_loss: 0.6921 G_loss: 1.5890
# Эпоха [1/100] Батч [17000/17229] D_lit_loss: 0.6966 D_conv_loss: 0.6852 G_loss: 1.6550
# Эпоха [1/100] Обучение--- D_lit_loss: 0.6905 D_conv_loss: 0.6894 G_loss: 1.8006 cycle_loss: 0.0521 identity_loss: 0.0481
# Эпоха [1/100] Валидация --- Val_D_lit_loss: 0.6907 Val_D_conv_loss: 0.6901 Val_G_loss: 1.6241 Val_cycle_loss: 0.0316 Val_identity_loss: 0.0280
# Модели перезаписаны в version_4 на 1 эпохе
# Эпоха [2/100] Батч [0/17229] D_lit_loss: 0.6950 D_conv_loss: 0.6926 G_loss: 1.6088
# Эпоха [2/100] Батч [500/17229] D_lit_loss: 0.6939 D_conv_loss: 0.6951 G_loss: 1.6156
# Эпоха [2/100] Батч [1000/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6953 G_loss: 1.7020
# Эпоха [2/100] Батч [1500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6904 G_loss: 1.6085
# Эпоха [2/100] Батч [2000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6888 G_loss: 1.6067
# Эпоха [2/100] Батч [2500/17229] D_lit_loss: 0.6911 D_conv_loss: 0.6907 G_loss: 1.6206
# Эпоха [2/100] Батч [3000/17229] D_lit_loss: 0.6910 D_conv_loss: 0.6904 G_loss: 1.6077
# Эпоха [2/100] Батч [3500/17229] D_lit_loss: 0.6912 D_conv_loss: 0.6890 G_loss: 1.6489
# Эпоха [2/100] Батч [4000/17229] D_lit_loss: 0.6876 D_conv_loss: 0.6872 G_loss: 1.6158
# Эпоха [2/100] Батч [4500/17229] D_lit_loss: 0.6976 D_conv_loss: 0.6977 G_loss: 1.6239
# Эпоха [2/100] Батч [5000/17229] D_lit_loss: 0.6937 D_conv_loss: 0.6912 G_loss: 1.5381
# Эпоха [2/100] Батч [5500/17229] D_lit_loss: 0.6888 D_conv_loss: 0.6853 G_loss: 1.6622
# Эпоха [2/100] Батч [6000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6927 G_loss: 1.5864
# Эпоха [2/100] Батч [6500/17229] D_lit_loss: 0.6915 D_conv_loss: 0.6969 G_loss: 1.6105
# Эпоха [2/100] Батч [7000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6940 G_loss: 1.5501
# Эпоха [2/100] Батч [7500/17229] D_lit_loss: 0.6853 D_conv_loss: 0.6899 G_loss: 1.6477
# Эпоха [2/100] Батч [8000/17229] D_lit_loss: 0.6918 D_conv_loss: 0.6928 G_loss: 1.5382
# Эпоха [2/100] Батч [8500/17229] D_lit_loss: 0.6851 D_conv_loss: 0.6908 G_loss: 1.6096
# Эпоха [2/100] Батч [9000/17229] D_lit_loss: 0.6894 D_conv_loss: 0.6903 G_loss: 1.6005
# Эпоха [2/100] Батч [9500/17229] D_lit_loss: 0.6899 D_conv_loss: 0.6914 G_loss: 1.6130
# Эпоха [2/100] Батч [10000/17229] D_lit_loss: 0.6914 D_conv_loss: 0.6910 G_loss: 1.5699
# Эпоха [2/100] Батч [10500/17229] D_lit_loss: 0.6924 D_conv_loss: 0.6942 G_loss: 1.6619
# Эпоха [2/100] Батч [11000/17229] D_lit_loss: 0.6895 D_conv_loss: 0.6952 G_loss: 1.5624
# Эпоха [2/100] Батч [11500/17229] D_lit_loss: 0.6940 D_conv_loss: 0.6916 G_loss: 1.5801
# Эпоха [2/100] Батч [12000/17229] D_lit_loss: 0.6901 D_conv_loss: 0.6908 G_loss: 1.5951
# Эпоха [2/100] Батч [12500/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6966 G_loss: 1.5740
# Эпоха [2/100] Батч [13000/17229] D_lit_loss: 0.6865 D_conv_loss: 0.6882 G_loss: 1.5674
# Эпоха [2/100] Батч [13500/17229] D_lit_loss: 0.6940 D_conv_loss: 0.6918 G_loss: 1.5509
# Эпоха [2/100] Батч [14000/17229] D_lit_loss: 0.6900 D_conv_loss: 0.6911 G_loss: 1.5747
# Эпоха [2/100] Батч [14500/17229] D_lit_loss: 0.6940 D_conv_loss: 0.6941 G_loss: 1.5784
# Эпоха [2/100] Батч [15000/17229] D_lit_loss: 0.6909 D_conv_loss: 0.6902 G_loss: 1.5873
# Эпоха [2/100] Батч [15500/17229] D_lit_loss: 0.6896 D_conv_loss: 0.6922 G_loss: 1.5942
# Эпоха [2/100] Батч [16000/17229] D_lit_loss: 0.6923 D_conv_loss: 0.6909 G_loss: 1.5820
# Эпоха [2/100] Батч [16500/17229] D_lit_loss: 0.6888 D_conv_loss: 0.6939 G_loss: 1.5883
# Эпоха [2/100] Батч [17000/17229] D_lit_loss: 0.6989 D_conv_loss: 0.6951 G_loss: 1.5818
# Эпоха [2/100] Обучение--- D_lit_loss: 0.6910 D_conv_loss: 0.6908 G_loss: 1.5925 cycle_loss: 0.0266 identity_loss: 0.0230
# Эпоха [2/100] Валидация --- Val_D_lit_loss: 0.6937 Val_D_conv_loss: 0.6913 Val_G_loss: 1.5612 Val_cycle_loss: 0.0242 Val_identity_loss: 0.0202
# Модели перезаписаны в version_4 на 2 эпохе
# Эпоха [3/100] Батч [0/17229] D_lit_loss: 0.6954 D_conv_loss: 0.6910 G_loss: 1.5513
# Эпоха [3/100] Батч [500/17229] D_lit_loss: 0.6892 D_conv_loss: 0.6966 G_loss: 1.5969
# Эпоха [3/100] Батч [1000/17229] D_lit_loss: 0.6962 D_conv_loss: 0.6946 G_loss: 1.5705
# Эпоха [3/100] Батч [1500/17229] D_lit_loss: 0.6908 D_conv_loss: 0.6903 G_loss: 1.5670
# Эпоха [3/100] Батч [2000/17229] D_lit_loss: 0.6893 D_conv_loss: 0.6908 G_loss: 1.5449
# Эпоха [3/100] Батч [2500/17229] D_lit_loss: 0.6866 D_conv_loss: 0.6877 G_loss: 1.5360
# Эпоха [3/100] Батч [3000/17229] D_lit_loss: 0.6925 D_conv_loss: 0.6966 G_loss: 1.5707
# Эпоха [3/100] Батч [3500/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6912 G_loss: 1.5902
# Эпоха [3/100] Батч [4000/17229] D_lit_loss: 0.6903 D_conv_loss: 0.6938 G_loss: 1.5676
# Эпоха [3/100] Батч [4500/17229] D_lit_loss: 0.6934 D_conv_loss: 0.6926 G_loss: 1.5612
# Эпоха [3/100] Батч [5000/17229] D_lit_loss: 0.6875 D_conv_loss: 0.6918 G_loss: 1.5581
# Эпоха [3/100] Батч [5500/17229] D_lit_loss: 0.6920 D_conv_loss: 0.6900 G_loss: 1.5645
# Эпоха [3/100] Батч [6000/17229] D_lit_loss: 0.6901 D_conv_loss: 0.6881 G_loss: 1.5124
# Эпоха [3/100] Батч [6500/17229] D_lit_loss: 0.6953 D_conv_loss: 0.6900 G_loss: 1.5292
# Эпоха [3/100] Батч [7000/17229] D_lit_loss: 0.6870 D_conv_loss: 0.6912 G_loss: 1.5653
# Эпоха [3/100] Батч [7500/17229] D_lit_loss: 0.6855 D_conv_loss: 0.6907 G_loss: 1.5805
# Эпоха [3/100] Батч [8000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6915 G_loss: 1.5406
# Эпоха [3/100] Батч [8500/17229] D_lit_loss: 0.6920 D_conv_loss: 0.6910 G_loss: 1.5566
# Эпоха [3/100] Батч [9000/17229] D_lit_loss: 0.6892 D_conv_loss: 0.6924 G_loss: 1.5589
# Эпоха [3/100] Батч [9500/17229] D_lit_loss: 0.6937 D_conv_loss: 0.6917 G_loss: 1.5560
# Эпоха [3/100] Батч [10000/17229] D_lit_loss: 0.6923 D_conv_loss: 0.6922 G_loss: 1.5460
# Эпоха [3/100] Батч [10500/17229] D_lit_loss: 0.6883 D_conv_loss: 0.6927 G_loss: 1.5081
# Эпоха [3/100] Батч [11000/17229] D_lit_loss: 0.6925 D_conv_loss: 0.6892 G_loss: 1.5170
# Эпоха [3/100] Батч [11500/17229] D_lit_loss: 0.6914 D_conv_loss: 0.6926 G_loss: 1.5308
# Эпоха [3/100] Батч [12000/17229] D_lit_loss: 0.6908 D_conv_loss: 0.6903 G_loss: 1.5519
# Эпоха [3/100] Батч [12500/17229] D_lit_loss: 0.6939 D_conv_loss: 0.6917 G_loss: 1.5315
# Эпоха [3/100] Батч [13000/17229] D_lit_loss: 0.6852 D_conv_loss: 0.6912 G_loss: 1.5384
# Эпоха [3/100] Батч [13500/17229] D_lit_loss: 0.6922 D_conv_loss: 0.6911 G_loss: 1.5036
# Эпоха [3/100] Батч [14000/17229] D_lit_loss: 0.6905 D_conv_loss: 0.6921 G_loss: 1.5141
# Эпоха [3/100] Батч [14500/17229] D_lit_loss: 0.6949 D_conv_loss: 0.6935 G_loss: 1.5408
# Эпоха [3/100] Батч [15000/17229] D_lit_loss: 0.6913 D_conv_loss: 0.6901 G_loss: 1.5145
# Эпоха [3/100] Батч [15500/17229] D_lit_loss: 0.6900 D_conv_loss: 0.6937 G_loss: 1.5555
# Эпоха [3/100] Батч [16000/17229] D_lit_loss: 0.6971 D_conv_loss: 0.6917 G_loss: 1.5214
# Эпоха [3/100] Батч [16500/17229] D_lit_loss: 0.6937 D_conv_loss: 0.6934 G_loss: 1.5508
# Эпоха [3/100] Батч [17000/17229] D_lit_loss: 0.6911 D_conv_loss: 0.6895 G_loss: 1.5271
# Эпоха [3/100] Обучение--- D_lit_loss: 0.6908 D_conv_loss: 0.6914 G_loss: 1.5481 cycle_loss: 0.0209 identity_loss: 0.0178
# Эпоха [3/100] Валидация --- Val_D_lit_loss: 0.6896 Val_D_conv_loss: 0.6913 Val_G_loss: 1.5449 Val_cycle_loss: 0.0206 Val_identity_loss: 0.0167
# Модели перезаписаны в version_4 на 3 эпохе
# Эпоха [4/100] Батч [0/17229] D_lit_loss: 0.6934 D_conv_loss: 0.6910 G_loss: 1.5281
# Эпоха [4/100] Батч [500/17229] D_lit_loss: 0.6906 D_conv_loss: 0.6902 G_loss: 1.5377
# Эпоха [4/100] Батч [1000/17229] D_lit_loss: 0.6899 D_conv_loss: 0.6912 G_loss: 1.5323
# Эпоха [4/100] Батч [1500/17229] D_lit_loss: 0.6893 D_conv_loss: 0.6919 G_loss: 1.5335
# Эпоха [4/100] Батч [2000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6917 G_loss: 1.5203
# Эпоха [4/100] Батч [2500/17229] D_lit_loss: 0.6903 D_conv_loss: 0.6947 G_loss: 1.5150
# Эпоха [4/100] Батч [3000/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6910 G_loss: 1.5181
# Эпоха [4/100] Батч [3500/17229] D_lit_loss: 0.6888 D_conv_loss: 0.6915 G_loss: 1.5417
# Эпоха [4/100] Батч [4000/17229] D_lit_loss: 0.6890 D_conv_loss: 0.6934 G_loss: 1.5377
# Эпоха [4/100] Батч [4500/17229] D_lit_loss: 0.6901 D_conv_loss: 0.6936 G_loss: 1.5165
# Эпоха [4/100] Батч [5000/17229] D_lit_loss: 0.6887 D_conv_loss: 0.6939 G_loss: 1.5304
# Эпоха [4/100] Батч [5500/17229] D_lit_loss: 0.6879 D_conv_loss: 0.6905 G_loss: 1.5230
# Эпоха [4/100] Батч [6000/17229] D_lit_loss: 0.6916 D_conv_loss: 0.6924 G_loss: 1.5248
# Эпоха [4/100] Батч [6500/17229] D_lit_loss: 0.6927 D_conv_loss: 0.6908 G_loss: 1.5462
# Эпоха [4/100] Батч [7000/17229] D_lit_loss: 0.6870 D_conv_loss: 0.6908 G_loss: 1.5131
# Эпоха [4/100] Батч [7500/17229] D_lit_loss: 0.6867 D_conv_loss: 0.6933 G_loss: 1.5364
# Эпоха [4/100] Батч [8000/17229] D_lit_loss: 0.6915 D_conv_loss: 0.6948 G_loss: 1.4971
# Эпоха [4/100] Батч [8500/17229] D_lit_loss: 0.6889 D_conv_loss: 0.6929 G_loss: 1.5305
# Эпоха [4/100] Батч [9000/17229] D_lit_loss: 0.6871 D_conv_loss: 0.6897 G_loss: 1.5247
# Эпоха [4/100] Батч [9500/17229] D_lit_loss: 0.6900 D_conv_loss: 0.6916 G_loss: 1.5217
# Эпоха [4/100] Батч [10000/17229] D_lit_loss: 0.6968 D_conv_loss: 0.6915 G_loss: 1.5169
# Эпоха [4/100] Батч [10500/17229] D_lit_loss: 0.6925 D_conv_loss: 0.6931 G_loss: 1.5139
# Эпоха [4/100] Батч [11000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6939 G_loss: 1.5175
# Эпоха [4/100] Батч [11500/17229] D_lit_loss: 0.6937 D_conv_loss: 0.6924 G_loss: 1.5138
# Эпоха [4/100] Батч [12000/17229] D_lit_loss: 0.6861 D_conv_loss: 0.6928 G_loss: 1.4903
# Эпоха [4/100] Батч [12500/17229] D_lit_loss: 0.6912 D_conv_loss: 0.6924 G_loss: 1.5294
# Эпоха [4/100] Батч [13000/17229] D_lit_loss: 0.6926 D_conv_loss: 0.6916 G_loss: 1.5325
# Эпоха [4/100] Батч [13500/17229] D_lit_loss: 0.6898 D_conv_loss: 0.6945 G_loss: 1.5073
# Эпоха [4/100] Батч [14000/17229] D_lit_loss: 0.6924 D_conv_loss: 0.6931 G_loss: 1.5602
# Эпоха [4/100] Батч [14500/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6955 G_loss: 1.5254
# Эпоха [4/100] Батч [15000/17229] D_lit_loss: 0.6886 D_conv_loss: 0.6902 G_loss: 1.5324
# Эпоха [4/100] Батч [15500/17229] D_lit_loss: 0.6888 D_conv_loss: 0.6900 G_loss: 1.5487
# Эпоха [4/100] Батч [16000/17229] D_lit_loss: 0.6868 D_conv_loss: 0.6905 G_loss: 1.5050
# Эпоха [4/100] Батч [16500/17229] D_lit_loss: 0.6867 D_conv_loss: 0.6920 G_loss: 1.5013
# Эпоха [4/100] Батч [17000/17229] D_lit_loss: 0.6849 D_conv_loss: 0.6892 G_loss: 1.5199
# Эпоха [4/100] Обучение--- D_lit_loss: 0.6909 D_conv_loss: 0.6918 G_loss: 1.5244 cycle_loss: 0.0179 identity_loss: 0.0151
# Эпоха [4/100] Валидация --- Val_D_lit_loss: 0.6901 Val_D_conv_loss: 0.6919 Val_G_loss: 1.5179 Val_cycle_loss: 0.0174 Val_identity_loss: 0.0147
# Модели перезаписаны в version_4 на 4 эпохе
# Эпоха [5/100] Батч [0/17229] D_lit_loss: 0.6915 D_conv_loss: 0.6932 G_loss: 1.5051
# Эпоха [5/100] Батч [500/17229] D_lit_loss: 0.6903 D_conv_loss: 0.6916 G_loss: 1.4783
# Эпоха [5/100] Батч [1000/17229] D_lit_loss: 0.6906 D_conv_loss: 0.6936 G_loss: 1.4991
# Эпоха [5/100] Батч [1500/17229] D_lit_loss: 0.6914 D_conv_loss: 0.6927 G_loss: 1.4992
# Эпоха [5/100] Батч [2000/17229] D_lit_loss: 0.6886 D_conv_loss: 0.6921 G_loss: 1.5418
# Эпоха [5/100] Батч [2500/17229] D_lit_loss: 0.6871 D_conv_loss: 0.6932 G_loss: 1.5286
# Эпоха [5/100] Батч [3000/17229] D_lit_loss: 0.6924 D_conv_loss: 0.6921 G_loss: 1.5159
# Эпоха [5/100] Батч [3500/17229] D_lit_loss: 0.6912 D_conv_loss: 0.6891 G_loss: 1.5247
# Эпоха [5/100] Батч [4000/17229] D_lit_loss: 0.6893 D_conv_loss: 0.6917 G_loss: 1.5243
# Эпоха [5/100] Батч [4500/17229] D_lit_loss: 0.6916 D_conv_loss: 0.6922 G_loss: 1.5089
# Эпоха [5/100] Батч [5000/17229] D_lit_loss: 0.6894 D_conv_loss: 0.6907 G_loss: 1.5190
# Эпоха [5/100] Батч [5500/17229] D_lit_loss: 0.6860 D_conv_loss: 0.6935 G_loss: 1.5350
# Эпоха [5/100] Батч [6000/17229] D_lit_loss: 0.6847 D_conv_loss: 0.6902 G_loss: 1.5030
# Эпоха [5/100] Батч [6500/17229] D_lit_loss: 0.6890 D_conv_loss: 0.6906 G_loss: 1.5159
# Эпоха [5/100] Батч [7000/17229] D_lit_loss: 0.6904 D_conv_loss: 0.6929 G_loss: 1.4904
# Эпоха [5/100] Батч [7500/17229] D_lit_loss: 0.6922 D_conv_loss: 0.6915 G_loss: 1.5005
# Эпоха [5/100] Батч [8000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6927 G_loss: 1.4808
# Эпоха [5/100] Батч [8500/17229] D_lit_loss: 0.6919 D_conv_loss: 0.6925 G_loss: 1.4970
# Эпоха [5/100] Батч [9000/17229] D_lit_loss: 0.6915 D_conv_loss: 0.6926 G_loss: 1.5030
# Эпоха [5/100] Батч [9500/17229] D_lit_loss: 0.6940 D_conv_loss: 0.6939 G_loss: 1.5175
# Эпоха [5/100] Батч [10000/17229] D_lit_loss: 0.6910 D_conv_loss: 0.6904 G_loss: 1.5244
# Эпоха [5/100] Батч [10500/17229] D_lit_loss: 0.6867 D_conv_loss: 0.6927 G_loss: 1.5106
# Эпоха [5/100] Батч [11000/17229] D_lit_loss: 0.6887 D_conv_loss: 0.6907 G_loss: 1.5249
# Эпоха [5/100] Батч [11500/17229] D_lit_loss: 0.6899 D_conv_loss: 0.6898 G_loss: 1.4814
# Эпоха [5/100] Батч [12000/17229] D_lit_loss: 0.6856 D_conv_loss: 0.6934 G_loss: 1.5225
# Эпоха [5/100] Батч [12500/17229] D_lit_loss: 0.6908 D_conv_loss: 0.6925 G_loss: 1.5524
# Эпоха [5/100] Батч [13000/17229] D_lit_loss: 0.6959 D_conv_loss: 0.6924 G_loss: 1.5118
# Эпоха [5/100] Батч [13500/17229] D_lit_loss: 0.6880 D_conv_loss: 0.6909 G_loss: 1.5126
# Эпоха [5/100] Батч [14000/17229] D_lit_loss: 0.6880 D_conv_loss: 0.6899 G_loss: 1.4962
# Эпоха [5/100] Батч [14500/17229] D_lit_loss: 0.6893 D_conv_loss: 0.6916 G_loss: 1.5302
# Эпоха [5/100] Батч [15000/17229] D_lit_loss: 0.6919 D_conv_loss: 0.6939 G_loss: 1.5062
# Эпоха [5/100] Батч [15500/17229] D_lit_loss: 0.6939 D_conv_loss: 0.6925 G_loss: 1.5238
# Эпоха [5/100] Батч [16000/17229] D_lit_loss: 0.6884 D_conv_loss: 0.6930 G_loss: 1.4995
# Эпоха [5/100] Батч [16500/17229] D_lit_loss: 0.6876 D_conv_loss: 0.6909 G_loss: 1.5126
# Эпоха [5/100] Батч [17000/17229] D_lit_loss: 0.6834 D_conv_loss: 0.6913 G_loss: 1.4793
# Эпоха [5/100] Обучение--- D_lit_loss: 0.6906 D_conv_loss: 0.6918 G_loss: 1.5110 cycle_loss: 0.0160 identity_loss: 0.0136
# Эпоха [5/100] Валидация --- Val_D_lit_loss: 0.6923 Val_D_conv_loss: 0.6913 Val_G_loss: 1.5009 Val_cycle_loss: 0.0162 Val_identity_loss: 0.0130
# Debugging plot_losses:
# Length epochs_range: 5
# Length history['D_lit_train']: 5
# Length history['D_conv_train']: 5
# Length history['G_train']: 5
# Length history['cycle_train']: 5
# Length history['identity_train']: 5
# Length history['D_lit_val']: 5
# Length history['D_conv_val']: 5
# Length history['G_val']: 5
# Length history['cycle_val']: 5
# Length history['identity_val']: 5
# Модели перезаписаны в version_4 на 5 эпохе
# Эпоха [6/100] Батч [0/17229] D_lit_loss: 0.6941 D_conv_loss: 0.6884 G_loss: 1.4840
# Эпоха [6/100] Батч [500/17229] D_lit_loss: 0.6936 D_conv_loss: 0.6917 G_loss: 1.5087
# Эпоха [6/100] Батч [1000/17229] D_lit_loss: 0.6900 D_conv_loss: 0.6916 G_loss: 1.4978
# Эпоха [6/100] Батч [1500/17229] D_lit_loss: 0.6938 D_conv_loss: 0.6890 G_loss: 1.4754
# Эпоха [6/100] Батч [2000/17229] D_lit_loss: 0.6911 D_conv_loss: 0.6922 G_loss: 1.5216
# Эпоха [6/100] Батч [2500/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6911 G_loss: 1.5144
# Эпоха [6/100] Батч [3000/17229] D_lit_loss: 0.6882 D_conv_loss: 0.6932 G_loss: 1.5486
# Эпоха [6/100] Батч [3500/17229] D_lit_loss: 0.6914 D_conv_loss: 0.6914 G_loss: 1.5110
# Эпоха [6/100] Батч [4000/17229] D_lit_loss: 0.6937 D_conv_loss: 0.6921 G_loss: 1.4932
# Эпоха [6/100] Батч [4500/17229] D_lit_loss: 0.6903 D_conv_loss: 0.6909 G_loss: 1.4994
# Эпоха [6/100] Батч [5000/17229] D_lit_loss: 0.6918 D_conv_loss: 0.6921 G_loss: 1.5107
# Эпоха [6/100] Батч [5500/17229] D_lit_loss: 0.6886 D_conv_loss: 0.6924 G_loss: 1.5158
# Эпоха [6/100] Батч [6000/17229] D_lit_loss: 0.6901 D_conv_loss: 0.6925 G_loss: 1.5135
# Эпоха [6/100] Батч [6500/17229] D_lit_loss: 0.6867 D_conv_loss: 0.6873 G_loss: 1.4832
# Эпоха [6/100] Батч [7000/17229] D_lit_loss: 0.6895 D_conv_loss: 0.6913 G_loss: 1.4925
# Эпоха [6/100] Батч [7500/17229] D_lit_loss: 0.6895 D_conv_loss: 0.6915 G_loss: 1.5121
# Эпоха [6/100] Батч [8000/17229] D_lit_loss: 0.6903 D_conv_loss: 0.6941 G_loss: 1.5104
# Эпоха [6/100] Батч [8500/17229] D_lit_loss: 0.6903 D_conv_loss: 0.6916 G_loss: 1.5014
# Эпоха [6/100] Батч [9000/17229] D_lit_loss: 0.6917 D_conv_loss: 0.6916 G_loss: 1.5069
# Эпоха [6/100] Батч [9500/17229] D_lit_loss: 0.6903 D_conv_loss: 0.6908 G_loss: 1.4888
# Эпоха [6/100] Батч [10000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6915 G_loss: 1.4907
# Эпоха [6/100] Батч [10500/17229] D_lit_loss: 0.6945 D_conv_loss: 0.6898 G_loss: 1.5113
# Эпоха [6/100] Батч [11000/17229] D_lit_loss: 0.6910 D_conv_loss: 0.6918 G_loss: 1.4958
# Эпоха [6/100] Батч [11500/17229] D_lit_loss: 0.6911 D_conv_loss: 0.6943 G_loss: 1.5099
# Эпоха [6/100] Батч [12000/17229] D_lit_loss: 0.6916 D_conv_loss: 0.6916 G_loss: 1.4794
# Эпоха [6/100] Батч [12500/17229] D_lit_loss: 0.6937 D_conv_loss: 0.6907 G_loss: 1.4804
# Эпоха [6/100] Батч [13000/17229] D_lit_loss: 0.6911 D_conv_loss: 0.6922 G_loss: 1.4951
# Эпоха [6/100] Батч [13500/17229] D_lit_loss: 0.6912 D_conv_loss: 0.6907 G_loss: 1.5225
# Эпоха [6/100] Батч [14000/17229] D_lit_loss: 0.6884 D_conv_loss: 0.6924 G_loss: 1.5025
# Эпоха [6/100] Батч [14500/17229] D_lit_loss: 0.6911 D_conv_loss: 0.6926 G_loss: 1.4825
# Эпоха [6/100] Батч [15000/17229] D_lit_loss: 0.6945 D_conv_loss: 0.6915 G_loss: 1.4772
# Эпоха [6/100] Батч [15500/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6916 G_loss: 1.4926
# Эпоха [6/100] Батч [16000/17229] D_lit_loss: 0.6904 D_conv_loss: 0.6897 G_loss: 1.4625
# Эпоха [6/100] Батч [16500/17229] D_lit_loss: 0.6917 D_conv_loss: 0.6915 G_loss: 1.4719
# Эпоха [6/100] Батч [17000/17229] D_lit_loss: 0.6934 D_conv_loss: 0.6945 G_loss: 1.4967
# Эпоха [6/100] Обучение--- D_lit_loss: 0.6915 D_conv_loss: 0.6918 G_loss: 1.4991 cycle_loss: 0.0146 identity_loss: 0.0124
# Эпоха [6/100] Валидация --- Val_D_lit_loss: 0.6927 Val_D_conv_loss: 0.6928 Val_G_loss: 1.5000 Val_cycle_loss: 0.0152 Val_identity_loss: 0.0128
# Модели перезаписаны в version_4 на 6 эпохе
# Эпоха [7/100] Батч [0/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6926 G_loss: 1.5098
# Эпоха [7/100] Батч [500/17229] D_lit_loss: 0.6893 D_conv_loss: 0.6908 G_loss: 1.5349
# Эпоха [7/100] Батч [1000/17229] D_lit_loss: 0.6923 D_conv_loss: 0.6951 G_loss: 1.4955
# Эпоха [7/100] Батч [1500/17229] D_lit_loss: 0.6882 D_conv_loss: 0.6931 G_loss: 1.5148
# Эпоха [7/100] Батч [2000/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6904 G_loss: 1.4917
# Эпоха [7/100] Батч [2500/17229] D_lit_loss: 0.6921 D_conv_loss: 0.6937 G_loss: 1.4885
# Эпоха [7/100] Батч [3000/17229] D_lit_loss: 0.6922 D_conv_loss: 0.6920 G_loss: 1.4990
# Эпоха [7/100] Батч [3500/17229] D_lit_loss: 0.6911 D_conv_loss: 0.6913 G_loss: 1.4670
# Эпоха [7/100] Батч [4000/17229] D_lit_loss: 0.6897 D_conv_loss: 0.6912 G_loss: 1.4913
# Эпоха [7/100] Батч [4500/17229] D_lit_loss: 0.6900 D_conv_loss: 0.6931 G_loss: 1.4707
# Эпоха [7/100] Батч [5000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6919 G_loss: 1.4823
# Эпоха [7/100] Батч [5500/17229] D_lit_loss: 0.6934 D_conv_loss: 0.6928 G_loss: 1.4937
# Эпоха [7/100] Батч [6000/17229] D_lit_loss: 0.6899 D_conv_loss: 0.6908 G_loss: 1.5013
# Эпоха [7/100] Батч [6500/17229] D_lit_loss: 0.6904 D_conv_loss: 0.6896 G_loss: 1.4719
# Эпоха [7/100] Батч [7000/17229] D_lit_loss: 0.6907 D_conv_loss: 0.6931 G_loss: 1.5462
# Эпоха [7/100] Батч [7500/17229] D_lit_loss: 0.6905 D_conv_loss: 0.6921 G_loss: 1.5030
# Эпоха [7/100] Батч [8000/17229] D_lit_loss: 0.6941 D_conv_loss: 0.6913 G_loss: 1.5096
# Эпоха [7/100] Батч [8500/17229] D_lit_loss: 0.6946 D_conv_loss: 0.6926 G_loss: 1.5249
# Эпоха [7/100] Батч [9000/17229] D_lit_loss: 0.6915 D_conv_loss: 0.6913 G_loss: 1.4861
# Эпоха [7/100] Батч [9500/17229] D_lit_loss: 0.6902 D_conv_loss: 0.6920 G_loss: 1.4658
# Эпоха [7/100] Батч [10000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6945 G_loss: 1.4836
# Эпоха [7/100] Батч [10500/17229] D_lit_loss: 0.6927 D_conv_loss: 0.6904 G_loss: 1.4941
# Эпоха [7/100] Батч [11000/17229] D_lit_loss: 0.6918 D_conv_loss: 0.6884 G_loss: 1.4923
# Эпоха [7/100] Батч [11500/17229] D_lit_loss: 0.6906 D_conv_loss: 0.6898 G_loss: 1.4880
# Эпоха [7/100] Батч [12000/17229] D_lit_loss: 0.6926 D_conv_loss: 0.6924 G_loss: 1.4756
# Эпоха [7/100] Батч [12500/17229] D_lit_loss: 0.6934 D_conv_loss: 0.6912 G_loss: 1.4582
# Эпоха [7/100] Батч [13000/17229] D_lit_loss: 0.6923 D_conv_loss: 0.6919 G_loss: 1.4862
# Эпоха [7/100] Батч [13500/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6914 G_loss: 1.4822
# Эпоха [7/100] Батч [14000/17229] D_lit_loss: 0.6905 D_conv_loss: 0.6904 G_loss: 1.4917
# Эпоха [7/100] Батч [14500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6909 G_loss: 1.4809
# Эпоха [7/100] Батч [15000/17229] D_lit_loss: 0.6926 D_conv_loss: 0.6896 G_loss: 1.4753
# Эпоха [7/100] Батч [15500/17229] D_lit_loss: 0.6946 D_conv_loss: 0.6936 G_loss: 1.4768
# Эпоха [7/100] Батч [16000/17229] D_lit_loss: 0.6909 D_conv_loss: 0.6928 G_loss: 1.4641
# Эпоха [7/100] Батч [16500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6931 G_loss: 1.4955
# Эпоха [7/100] Батч [17000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6923 G_loss: 1.4899
# Эпоха [7/100] Обучение--- D_lit_loss: 0.6920 D_conv_loss: 0.6920 G_loss: 1.4888 cycle_loss: 0.0133 identity_loss: 0.0114
# Эпоха [7/100] Валидация --- Val_D_lit_loss: 0.6916 Val_D_conv_loss: 0.6916 Val_G_loss: 1.4881 Val_cycle_loss: 0.0133 Val_identity_loss: 0.0110
# Модели перезаписаны в version_4 на 7 эпохе
# Эпоха [8/100] Батч [0/17229] D_lit_loss: 0.6918 D_conv_loss: 0.6923 G_loss: 1.4736
# Эпоха [8/100] Батч [500/17229] D_lit_loss: 0.6925 D_conv_loss: 0.6917 G_loss: 1.4992
# Эпоха [8/100] Батч [1000/17229] D_lit_loss: 0.6924 D_conv_loss: 0.6916 G_loss: 1.4758
# Эпоха [8/100] Батч [1500/17229] D_lit_loss: 0.6915 D_conv_loss: 0.6929 G_loss: 1.4854
# Эпоха [8/100] Батч [2000/17229] D_lit_loss: 0.6912 D_conv_loss: 0.6924 G_loss: 1.4856
# Эпоха [8/100] Батч [2500/17229] D_lit_loss: 0.6923 D_conv_loss: 0.6926 G_loss: 1.4778
# Эпоха [8/100] Батч [3000/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6926 G_loss: 1.4767
# Эпоха [8/100] Батч [3500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6929 G_loss: 1.4566
# Эпоха [8/100] Батч [4000/17229] D_lit_loss: 0.6941 D_conv_loss: 0.6916 G_loss: 1.4968
# Эпоха [8/100] Батч [4500/17229] D_lit_loss: 0.6935 D_conv_loss: 0.6920 G_loss: 1.4515
# Эпоха [8/100] Батч [5000/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6913 G_loss: 1.4752
# Эпоха [8/100] Батч [5500/17229] D_lit_loss: 0.6917 D_conv_loss: 0.6922 G_loss: 1.4775
# Эпоха [8/100] Батч [6000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6912 G_loss: 1.4641
# Эпоха [8/100] Батч [6500/17229] D_lit_loss: 0.6923 D_conv_loss: 0.6934 G_loss: 1.4797
# Эпоха [8/100] Батч [7000/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6915 G_loss: 1.4882
# Эпоха [8/100] Батч [7500/17229] D_lit_loss: 0.6926 D_conv_loss: 0.6926 G_loss: 1.4694
# Эпоха [8/100] Батч [8000/17229] D_lit_loss: 0.6926 D_conv_loss: 0.6897 G_loss: 1.4635
# Эпоха [8/100] Батч [8500/17229] D_lit_loss: 0.6942 D_conv_loss: 0.6936 G_loss: 1.4700
# Эпоха [8/100] Батч [9000/17229] D_lit_loss: 0.6948 D_conv_loss: 0.6942 G_loss: 1.4871
# Эпоха [8/100] Батч [9500/17229] D_lit_loss: 0.6941 D_conv_loss: 0.6920 G_loss: 1.4483
# Эпоха [8/100] Батч [10000/17229] D_lit_loss: 0.6923 D_conv_loss: 0.6934 G_loss: 1.5055
# Эпоха [8/100] Батч [10500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6909 G_loss: 1.4761
# Эпоха [8/100] Батч [11000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6932 G_loss: 1.4657
# Эпоха [8/100] Батч [11500/17229] D_lit_loss: 0.6912 D_conv_loss: 0.6932 G_loss: 1.4914
# Эпоха [8/100] Батч [12000/17229] D_lit_loss: 0.6924 D_conv_loss: 0.6925 G_loss: 1.4896
# Эпоха [8/100] Батч [12500/17229] D_lit_loss: 0.6924 D_conv_loss: 0.6932 G_loss: 1.4910
# Эпоха [8/100] Батч [13000/17229] D_lit_loss: 0.6927 D_conv_loss: 0.6910 G_loss: 1.4979
# Эпоха [8/100] Батч [13500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6927 G_loss: 1.4943
# Эпоха [8/100] Батч [14000/17229] D_lit_loss: 0.6926 D_conv_loss: 0.6915 G_loss: 1.4721
# Эпоха [8/100] Батч [14500/17229] D_lit_loss: 0.6924 D_conv_loss: 0.6913 G_loss: 1.4779
# Эпоха [8/100] Батч [15000/17229] D_lit_loss: 0.6925 D_conv_loss: 0.6900 G_loss: 1.4723
# Эпоха [8/100] Батч [15500/17229] D_lit_loss: 0.6935 D_conv_loss: 0.6921 G_loss: 1.4929
# Эпоха [8/100] Батч [16000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6920 G_loss: 1.4642
# Эпоха [8/100] Батч [16500/17229] D_lit_loss: 0.6923 D_conv_loss: 0.6934 G_loss: 1.4818
# Эпоха [8/100] Батч [17000/17229] D_lit_loss: 0.6924 D_conv_loss: 0.6910 G_loss: 1.4679
# Эпоха [8/100] Обучение--- D_lit_loss: 0.6926 D_conv_loss: 0.6921 G_loss: 1.4796 cycle_loss: 0.0122 identity_loss: 0.0105
# Эпоха [8/100] Валидация --- Val_D_lit_loss: 0.6927 Val_D_conv_loss: 0.6921 Val_G_loss: 1.4823 Val_cycle_loss: 0.0127 Val_identity_loss: 0.0107
# Модели перезаписаны в version_4 на 8 эпохе
# Эпоха [9/100] Батч [0/17229] D_lit_loss: 0.6917 D_conv_loss: 0.6910 G_loss: 1.4776
# Эпоха [9/100] Батч [500/17229] D_lit_loss: 0.6922 D_conv_loss: 0.6933 G_loss: 1.4760
# Эпоха [9/100] Батч [1000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6917 G_loss: 1.4877
# Эпоха [9/100] Батч [1500/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6945 G_loss: 1.5022
# Эпоха [9/100] Батч [2000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6918 G_loss: 1.4821
# Эпоха [9/100] Батч [2500/17229] D_lit_loss: 0.6926 D_conv_loss: 0.6922 G_loss: 1.4758
# Эпоха [9/100] Батч [3000/17229] D_lit_loss: 0.6923 D_conv_loss: 0.6920 G_loss: 1.4656
# Эпоха [9/100] Батч [3500/17229] D_lit_loss: 0.6926 D_conv_loss: 0.6919 G_loss: 1.4862
# Эпоха [9/100] Батч [4000/17229] D_lit_loss: 0.6925 D_conv_loss: 0.6919 G_loss: 1.4848
# Эпоха [9/100] Батч [4500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6916 G_loss: 1.4695
# Эпоха [9/100] Батч [5000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6925 G_loss: 1.4800
# Эпоха [9/100] Батч [5500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6922 G_loss: 1.4629
# Эпоха [9/100] Батч [6000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6922 G_loss: 1.4786
# Эпоха [9/100] Батч [6500/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6901 G_loss: 1.4889
# Эпоха [9/100] Батч [7000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6958 G_loss: 1.4764
# Эпоха [9/100] Батч [7500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6929 G_loss: 1.4464
# Эпоха [9/100] Батч [8000/17229] D_lit_loss: 0.6925 D_conv_loss: 0.6921 G_loss: 1.4700
# Эпоха [9/100] Батч [8500/17229] D_lit_loss: 0.6935 D_conv_loss: 0.6909 G_loss: 1.4603
# Эпоха [9/100] Батч [9000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6908 G_loss: 1.4879
# Эпоха [9/100] Батч [9500/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6927 G_loss: 1.4714
# Эпоха [9/100] Батч [10000/17229] D_lit_loss: 0.6926 D_conv_loss: 0.6931 G_loss: 1.4806
# Эпоха [9/100] Батч [10500/17229] D_lit_loss: 0.6925 D_conv_loss: 0.6932 G_loss: 1.4959
# Эпоха [9/100] Батч [11000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6917 G_loss: 1.4588
# Эпоха [9/100] Батч [11500/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6944 G_loss: 1.4674
# Эпоха [9/100] Батч [12000/17229] D_lit_loss: 0.6934 D_conv_loss: 0.6919 G_loss: 1.4582
# Эпоха [9/100] Батч [12500/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6892 G_loss: 1.4720
# Эпоха [9/100] Батч [13000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6912 G_loss: 1.4770
# Эпоха [9/100] Батч [13500/17229] D_lit_loss: 0.6927 D_conv_loss: 0.6880 G_loss: 1.4615
# Эпоха [9/100] Батч [14000/17229] D_lit_loss: 0.6927 D_conv_loss: 0.6920 G_loss: 1.4615
# Эпоха [9/100] Батч [14500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6924 G_loss: 1.4837
# Эпоха [9/100] Батч [15000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6941 G_loss: 1.4601
# Эпоха [9/100] Батч [15500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6903 G_loss: 1.4673
# Эпоха [9/100] Батч [16000/17229] D_lit_loss: 0.6934 D_conv_loss: 0.6919 G_loss: 1.4684
# Эпоха [9/100] Батч [16500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6911 G_loss: 1.4508
# Эпоха [9/100] Батч [17000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6901 G_loss: 1.4741
# Эпоха [9/100] Обучение--- D_lit_loss: 0.6930 D_conv_loss: 0.6919 G_loss: 1.4736 cycle_loss: 0.0114 identity_loss: 0.0099
# Эпоха [9/100] Валидация --- Val_D_lit_loss: 0.6931 Val_D_conv_loss: 0.6919 Val_G_loss: 1.4724 Val_cycle_loss: 0.0114 Val_identity_loss: 0.0101
# Модели перезаписаны в version_4 на 9 эпохе
# Эпоха [10/100] Батч [0/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6911 G_loss: 1.4461
# Эпоха [10/100] Батч [500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6919 G_loss: 1.4502
# Эпоха [10/100] Батч [1000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6934 G_loss: 1.4800
# Эпоха [10/100] Батч [1500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6937 G_loss: 1.4684
# Эпоха [10/100] Батч [2000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6902 G_loss: 1.4786
# Эпоха [10/100] Батч [2500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6891 G_loss: 1.4528
# Эпоха [10/100] Батч [3000/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6911 G_loss: 1.4566
# Эпоха [10/100] Батч [3500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6913 G_loss: 1.4507
# Эпоха [10/100] Батч [4000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6892 G_loss: 1.4529
# Эпоха [10/100] Батч [4500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6920 G_loss: 1.4650
# Эпоха [10/100] Батч [5000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6890 G_loss: 1.4803
# Эпоха [10/100] Батч [5500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6926 G_loss: 1.4798
# Эпоха [10/100] Батч [6000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6918 G_loss: 1.4679
# Эпоха [10/100] Батч [6500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6901 G_loss: 1.4686
# Эпоха [10/100] Батч [7000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6917 G_loss: 1.4910
# Эпоха [10/100] Батч [7500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6942 G_loss: 1.4567
# Эпоха [10/100] Батч [8000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6919 G_loss: 1.4411
# Эпоха [10/100] Батч [8500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6917 G_loss: 1.4735
# Эпоха [10/100] Батч [9000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6921 G_loss: 1.4960
# Эпоха [10/100] Батч [9500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6928 G_loss: 1.4788
# Эпоха [10/100] Батч [10000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6918 G_loss: 1.4743
# Эпоха [10/100] Батч [10500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6920 G_loss: 1.4667
# Эпоха [10/100] Батч [11000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6939 G_loss: 1.4466
# Эпоха [10/100] Батч [11500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6940 G_loss: 1.4689
# Эпоха [10/100] Батч [12000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6906 G_loss: 1.4577
# Эпоха [10/100] Батч [12500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6909 G_loss: 1.4793
# Эпоха [10/100] Батч [13000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6922 G_loss: 1.4715
# Эпоха [10/100] Батч [13500/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6930 G_loss: 1.4752
# Эпоха [10/100] Батч [14000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6916 G_loss: 1.4429
# Эпоха [10/100] Батч [14500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6881 G_loss: 1.4603
# Эпоха [10/100] Батч [15000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6913 G_loss: 1.4465
# Эпоха [10/100] Батч [15500/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6929 G_loss: 1.4570
# Эпоха [10/100] Батч [16000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6925 G_loss: 1.4589
# Эпоха [10/100] Батч [16500/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6905 G_loss: 1.4710
# Эпоха [10/100] Батч [17000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6945 G_loss: 1.5006
# Эпоха [10/100] Обучение--- D_lit_loss: 0.6931 D_conv_loss: 0.6919 G_loss: 1.4691 cycle_loss: 0.0108 identity_loss: 0.0095
# Эпоха [10/100] Валидация --- Val_D_lit_loss: 0.6931 Val_D_conv_loss: 0.6914 Val_G_loss: 1.4739 Val_cycle_loss: 0.0116 Val_identity_loss: 0.0099
# Debugging plot_losses:
# Length epochs_range: 10
# Length history['D_lit_train']: 10
# Length history['D_conv_train']: 10
# Length history['G_train']: 10
# Length history['cycle_train']: 10
# Length history['identity_train']: 10
# Length history['D_lit_val']: 10
# Length history['D_conv_val']: 10
# Length history['G_val']: 10
# Length history['cycle_val']: 10
# Length history['identity_val']: 10
# Модели перезаписаны в version_4 на 10 эпохе
# Эпоха [11/100] Батч [0/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6906 G_loss: 1.4816
# Эпоха [11/100] Батч [500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6913 G_loss: 1.4407
# Эпоха [11/100] Батч [1000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6913 G_loss: 1.4391
# Эпоха [11/100] Батч [1500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6927 G_loss: 1.4703
# Эпоха [11/100] Батч [2000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6933 G_loss: 1.4865
# Эпоха [11/100] Батч [2500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6933 G_loss: 1.4760
# Эпоха [11/100] Батч [3000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6930 G_loss: 1.4867
# Эпоха [11/100] Батч [3500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6911 G_loss: 1.4738
# Эпоха [11/100] Батч [4000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6921 G_loss: 1.4736
# Эпоха [11/100] Батч [4500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6922 G_loss: 1.4609
# Эпоха [11/100] Батч [5000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6912 G_loss: 1.4760
# Эпоха [11/100] Батч [5500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6911 G_loss: 1.4756
# Эпоха [11/100] Батч [6000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6916 G_loss: 1.4919
# Эпоха [11/100] Батч [6500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6918 G_loss: 1.4731
# Эпоха [11/100] Батч [7000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6902 G_loss: 1.4537
# Эпоха [11/100] Батч [7500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6940 G_loss: 1.4738
# Эпоха [11/100] Батч [8000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6902 G_loss: 1.4805
# Эпоха [11/100] Батч [8500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6895 G_loss: 1.4976
# Эпоха [11/100] Батч [9000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6897 G_loss: 1.4641
# Эпоха [11/100] Батч [9500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6939 G_loss: 1.4518
# Эпоха [11/100] Батч [10000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6927 G_loss: 1.4806
# Эпоха [11/100] Батч [10500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6887 G_loss: 1.4461
# Эпоха [11/100] Батч [11000/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6914 G_loss: 1.4646
# Эпоха [11/100] Батч [11500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6923 G_loss: 1.4576
# Эпоха [11/100] Батч [12000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6927 G_loss: 1.4460
# Эпоха [11/100] Батч [12500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6941 G_loss: 1.4562
# Эпоха [11/100] Батч [13000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6932 G_loss: 1.4516
# Эпоха [11/100] Батч [13500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6889 G_loss: 1.4848
# Эпоха [11/100] Батч [14000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6910 G_loss: 1.4556
# Эпоха [11/100] Батч [14500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6952 G_loss: 1.4462
# Эпоха [11/100] Батч [15000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6917 G_loss: 1.4915
# Эпоха [11/100] Батч [15500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6937 G_loss: 1.4654
# Эпоха [11/100] Батч [16000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6925 G_loss: 1.4733
# Эпоха [11/100] Батч [16500/17229] D_lit_loss: 0.6935 D_conv_loss: 0.6926 G_loss: 1.4420
# Эпоха [11/100] Батч [17000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6940 G_loss: 1.4808
# Эпоха [11/100] Обучение--- D_lit_loss: 0.6931 D_conv_loss: 0.6920 G_loss: 1.4655 cycle_loss: 0.0103 identity_loss: 0.0091
# Эпоха [11/100] Валидация --- Val_D_lit_loss: 0.6931 Val_D_conv_loss: 0.6920 Val_G_loss: 1.4664 Val_cycle_loss: 0.0105 Val_identity_loss: 0.0092
# Модели перезаписаны в version_4 на 11 эпохе
# Эпоха [12/100] Батч [0/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6909 G_loss: 1.4475
# Эпоха [12/100] Батч [500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6919 G_loss: 1.4412
# Эпоха [12/100] Батч [1000/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6933 G_loss: 1.4616
# Эпоха [12/100] Батч [1500/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6908 G_loss: 1.4558
# Эпоха [12/100] Батч [2000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6925 G_loss: 1.4589
# Эпоха [12/100] Батч [2500/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6908 G_loss: 1.4308
# Эпоха [12/100] Батч [3000/17229] D_lit_loss: 0.6934 D_conv_loss: 0.6916 G_loss: 1.4675
# Эпоха [12/100] Батч [3500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6947 G_loss: 1.4396
# Эпоха [12/100] Батч [4000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6919 G_loss: 1.4764
# Эпоха [12/100] Батч [4500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6914 G_loss: 1.4530
# Эпоха [12/100] Батч [5000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6925 G_loss: 1.4423
# Эпоха [12/100] Батч [5500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6912 G_loss: 1.4557
# Эпоха [12/100] Батч [6000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6916 G_loss: 1.4491
# Эпоха [12/100] Батч [6500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6948 G_loss: 1.4430
# Эпоха [12/100] Батч [7000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6925 G_loss: 1.4799
# Эпоха [12/100] Батч [7500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6920 G_loss: 1.4648
# Эпоха [12/100] Батч [8000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6918 G_loss: 1.4602
# Эпоха [12/100] Батч [8500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6932 G_loss: 1.4662
# Эпоха [12/100] Батч [9000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6938 G_loss: 1.4472
# Эпоха [12/100] Батч [9500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6926 G_loss: 1.4596
# Эпоха [12/100] Батч [10000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6922 G_loss: 1.4389
# Эпоха [12/100] Батч [10500/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6922 G_loss: 1.4686
# Эпоха [12/100] Батч [11000/17229] D_lit_loss: 0.6934 D_conv_loss: 0.6929 G_loss: 1.4575
# Эпоха [12/100] Батч [11500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6949 G_loss: 1.4560
# Эпоха [12/100] Батч [12000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6940 G_loss: 1.4520
# Эпоха [12/100] Батч [12500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6915 G_loss: 1.4612
# Эпоха [12/100] Батч [13000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6916 G_loss: 1.4468
# Эпоха [12/100] Батч [13500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6907 G_loss: 1.4487
# Эпоха [12/100] Батч [14000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6919 G_loss: 1.4732
# Эпоха [12/100] Батч [14500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6936 G_loss: 1.4485
# Эпоха [12/100] Батч [15000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6914 G_loss: 1.4582
# Эпоха [12/100] Батч [15500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6898 G_loss: 1.4321
# Эпоха [12/100] Батч [16000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6944 G_loss: 1.4386
# Эпоха [12/100] Батч [16500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6910 G_loss: 1.4592
# Эпоха [12/100] Батч [17000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6917 G_loss: 1.4585
# Эпоха [12/100] Обучение--- D_lit_loss: 0.6931 D_conv_loss: 0.6920 G_loss: 1.4622 cycle_loss: 0.0098 identity_loss: 0.0088
# Эпоха [12/100] Валидация --- Val_D_lit_loss: 0.6931 Val_D_conv_loss: 0.6920 Val_G_loss: 1.4664 Val_cycle_loss: 0.0105 Val_identity_loss: 0.0092
# Модели перезаписаны в version_4 на 12 эпохе
# Эпоха [13/100] Батч [0/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6935 G_loss: 1.4620
# Эпоха [13/100] Батч [500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6932 G_loss: 1.4693
# Эпоха [13/100] Батч [1000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6924 G_loss: 1.4501
# Эпоха [13/100] Батч [1500/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6937 G_loss: 1.4522
# Эпоха [13/100] Батч [2000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6932 G_loss: 1.4648
# Эпоха [13/100] Батч [2500/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6922 G_loss: 1.4733
# Эпоха [13/100] Батч [3000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6896 G_loss: 1.4628
# Эпоха [13/100] Батч [3500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6930 G_loss: 1.4693
# Эпоха [13/100] Батч [4000/17229] D_lit_loss: 0.6927 D_conv_loss: 0.6925 G_loss: 1.4596
# Эпоха [13/100] Батч [4500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6909 G_loss: 1.4558
# Эпоха [13/100] Батч [5000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6938 G_loss: 1.4703
# Эпоха [13/100] Батч [5500/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6923 G_loss: 1.4442
# Эпоха [13/100] Батч [6000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6931 G_loss: 1.4605
# Эпоха [13/100] Батч [6500/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6923 G_loss: 1.4488
# Эпоха [13/100] Батч [7000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6912 G_loss: 1.4501
# Эпоха [13/100] Батч [7500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6907 G_loss: 1.4558
# Эпоха [13/100] Батч [8000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6897 G_loss: 1.4944
# Эпоха [13/100] Батч [8500/17229] D_lit_loss: 0.6920 D_conv_loss: 0.6909 G_loss: 1.4547
# Эпоха [13/100] Батч [9000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6933 G_loss: 1.4486
# Эпоха [13/100] Батч [9500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6932 G_loss: 1.4443
# Эпоха [13/100] Батч [10000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6901 G_loss: 1.4409
# Эпоха [13/100] Батч [10500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6912 G_loss: 1.4693
# Эпоха [13/100] Батч [11000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6893 G_loss: 1.4557
# Эпоха [13/100] Батч [11500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6951 G_loss: 1.5215
# Эпоха [13/100] Батч [12000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6911 G_loss: 1.4436
# Эпоха [13/100] Батч [12500/17229] D_lit_loss: 0.6927 D_conv_loss: 0.6905 G_loss: 1.4586
# Эпоха [13/100] Батч [13000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6904 G_loss: 1.4662
# Эпоха [13/100] Батч [13500/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6907 G_loss: 1.4534
# Эпоха [13/100] Батч [14000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6923 G_loss: 1.4651
# Эпоха [13/100] Батч [14500/17229] D_lit_loss: 0.6934 D_conv_loss: 0.6930 G_loss: 1.5089
# Эпоха [13/100] Батч [15000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6908 G_loss: 1.4506
# Эпоха [13/100] Батч [15500/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6920 G_loss: 1.4829
# Эпоха [13/100] Батч [16000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6927 G_loss: 1.4596
# Эпоха [13/100] Батч [16500/17229] D_lit_loss: 0.6926 D_conv_loss: 0.6910 G_loss: 1.4520
# Эпоха [13/100] Батч [17000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6922 G_loss: 1.4431
# Эпоха [13/100] Обучение--- D_lit_loss: 0.6931 D_conv_loss: 0.6921 G_loss: 1.4594 cycle_loss: 0.0094 identity_loss: 0.0085
# Эпоха [13/100] Валидация --- Val_D_lit_loss: 0.6929 Val_D_conv_loss: 0.6922 Val_G_loss: 1.4649 Val_cycle_loss: 0.0103 Val_identity_loss: 0.0092
# Модели перезаписаны в version_4 на 13 эпохе
# Эпоха [14/100] Батч [0/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6940 G_loss: 1.4759
# Эпоха [14/100] Батч [500/17229] D_lit_loss: 0.6927 D_conv_loss: 0.6929 G_loss: 1.4606
# Эпоха [14/100] Батч [1000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6925 G_loss: 1.4496
# Эпоха [14/100] Батч [1500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6918 G_loss: 1.4698
# Эпоха [14/100] Батч [2000/17229] D_lit_loss: 0.6934 D_conv_loss: 0.6930 G_loss: 1.4577
# Эпоха [14/100] Батч [2500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6923 G_loss: 1.4576
# Эпоха [14/100] Батч [3000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6941 G_loss: 1.4450
# Эпоха [14/100] Батч [3500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6918 G_loss: 1.4453
# Эпоха [14/100] Батч [4000/17229] D_lit_loss: 0.6921 D_conv_loss: 0.6899 G_loss: 1.4594
# Эпоха [14/100] Батч [4500/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6903 G_loss: 1.4595
# Эпоха [14/100] Батч [5000/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6904 G_loss: 1.4570
# Эпоха [14/100] Батч [5500/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6924 G_loss: 1.4544
# Эпоха [14/100] Батч [6000/17229] D_lit_loss: 0.6927 D_conv_loss: 0.6928 G_loss: 1.4439
# Эпоха [14/100] Батч [6500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6946 G_loss: 1.4483
# Эпоха [14/100] Батч [7000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6932 G_loss: 1.4573
# Эпоха [14/100] Батч [7500/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6939 G_loss: 1.4841
# Эпоха [14/100] Батч [8000/17229] D_lit_loss: 0.6925 D_conv_loss: 0.6927 G_loss: 1.4657
# Эпоха [14/100] Батч [8500/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6903 G_loss: 1.4359
# Эпоха [14/100] Батч [9000/17229] D_lit_loss: 0.6926 D_conv_loss: 0.6912 G_loss: 1.4687
# Эпоха [14/100] Батч [9500/17229] D_lit_loss: 0.6933 D_conv_loss: 0.6935 G_loss: 1.4580
# Эпоха [14/100] Батч [10000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6908 G_loss: 1.4689
# Эпоха [14/100] Батч [10500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6933 G_loss: 1.4482
# Эпоха [14/100] Батч [11000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6932 G_loss: 1.4743
# Эпоха [14/100] Батч [11500/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6905 G_loss: 1.4707
# Эпоха [14/100] Батч [12000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6915 G_loss: 1.4615
# Эпоха [14/100] Батч [12500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6929 G_loss: 1.4616
# Эпоха [14/100] Батч [13000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6921 G_loss: 1.4486
# Эпоха [14/100] Батч [13500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6914 G_loss: 1.4661
# Эпоха [14/100] Батч [14000/17229] D_lit_loss: 0.6927 D_conv_loss: 0.6916 G_loss: 1.4636
# Эпоха [14/100] Батч [14500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6916 G_loss: 1.4508
# Эпоха [14/100] Батч [15000/17229] D_lit_loss: 0.6912 D_conv_loss: 0.6911 G_loss: 1.4439
# Эпоха [14/100] Батч [15500/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6930 G_loss: 1.4558
# Эпоха [14/100] Батч [16000/17229] D_lit_loss: 0.6928 D_conv_loss: 0.6924 G_loss: 1.4724
# Эпоха [14/100] Батч [16500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6910 G_loss: 1.4510
# Эпоха [14/100] Батч [17000/17229] D_lit_loss: 0.6934 D_conv_loss: 0.6915 G_loss: 1.4385
# Эпоха [14/100] Обучение--- D_lit_loss: 0.6930 D_conv_loss: 0.6921 G_loss: 1.4574 cycle_loss: 0.0091 identity_loss: 0.0083
# Эпоха [14/100] Валидация --- Val_D_lit_loss: 0.6928 Val_D_conv_loss: 0.6917 Val_G_loss: 1.4621 Val_cycle_loss: 0.0098 Val_identity_loss: 0.0087
# Модели перезаписаны в version_4 на 14 эпохе
# Эпоха [15/100] Батч [0/17229] D_lit_loss: 0.6922 D_conv_loss: 0.6919 G_loss: 1.4641
# Эпоха [15/100] Батч [500/17229] D_lit_loss: 0.6926 D_conv_loss: 0.6907 G_loss: 1.4646
# Эпоха [15/100] Батч [1000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6928 G_loss: 1.4626
# Эпоха [15/100] Батч [1500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6959 G_loss: 1.4524
# Эпоха [15/100] Батч [2000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6903 G_loss: 1.4479
# ...
# Эпоха [96/100] Батч [7500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6931 G_loss: 1.4230
# Эпоха [96/100] Батч [8000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6934 G_loss: 1.4292
# Эпоха [96/100] Батч [8500/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6927 G_loss: 1.4147
# Эпоха [96/100] Батч [9000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6929 G_loss: 1.4141
# Эпоха [96/100] Батч [9500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6928 G_loss: 1.4192
# Эпоха [96/100] Батч [10000/17229] D_lit_loss: 0.6929 D_conv_loss: 0.6923 G_loss: 1.4337
# Эпоха [96/100] Батч [10500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6919 G_loss: 1.4240
# Эпоха [96/100] Батч [11000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6934 G_loss: 1.4344
# Эпоха [96/100] Батч [11500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6926 G_loss: 1.4441
# Эпоха [96/100] Батч [12000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6924 G_loss: 1.4191
# Эпоха [96/100] Батч [12500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6932 G_loss: 1.4187
# Эпоха [96/100] Батч [13000/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6933 G_loss: 1.4202
# Эпоха [96/100] Батч [13500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6932 G_loss: 1.4199
# Эпоха [96/100] Батч [14000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6920 G_loss: 1.4178
# Эпоха [96/100] Батч [14500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6929 G_loss: 1.4157
# Эпоха [96/100] Батч [15000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6925 G_loss: 1.4196
# Эпоха [96/100] Батч [15500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6927 G_loss: 1.4091
# Эпоха [96/100] Батч [16000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6915 G_loss: 1.4237
# Эпоха [96/100] Батч [16500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6928 G_loss: 1.4214
# Эпоха [96/100] Батч [17000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6927 G_loss: 1.4139
# Эпоха [96/100] Обучение--- D_lit_loss: 0.6930 D_conv_loss: 0.6928 G_loss: 1.4220 cycle_loss: 0.0046 identity_loss: 0.0041
# Эпоха [96/100] Валидация --- Val_D_lit_loss: 0.6931 Val_D_conv_loss: 0.6929 Val_G_loss: 1.4316 Val_cycle_loss: 0.0054 Val_identity_loss: 0.0059
# Модели перезаписаны в version_4 на 96 эпохе
# Эпоха [97/100] Батч [0/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6930 G_loss: 1.4134
# Эпоха [97/100] Батч [500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6929 G_loss: 1.4173
# Эпоха [97/100] Батч [1000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6928 G_loss: 1.4153
# Эпоха [97/100] Батч [1500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6939 G_loss: 1.4314
# Эпоха [97/100] Батч [2000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6922 G_loss: 1.4238
# Эпоха [97/100] Батч [2500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6926 G_loss: 1.4288
# Эпоха [97/100] Батч [3000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6928 G_loss: 1.4188
# Эпоха [97/100] Батч [3500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6924 G_loss: 1.4250
# Эпоха [97/100] Батч [4000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6930 G_loss: 1.4132
# Эпоха [97/100] Батч [4500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6943 G_loss: 1.4118
# Эпоха [97/100] Батч [5000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6932 G_loss: 1.4307
# Эпоха [97/100] Батч [5500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6935 G_loss: 1.4113
# Эпоха [97/100] Батч [6000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6929 G_loss: 1.4225
# Эпоха [97/100] Батч [6500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6937 G_loss: 1.4178
# Эпоха [97/100] Батч [7000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6933 G_loss: 1.4230
# Эпоха [97/100] Батч [7500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6923 G_loss: 1.4449
# Эпоха [97/100] Батч [8000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6933 G_loss: 1.4243
# Эпоха [97/100] Батч [8500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6926 G_loss: 1.4255
# Эпоха [97/100] Батч [9000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6926 G_loss: 1.4177
# Эпоха [97/100] Батч [9500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6931 G_loss: 1.4303
# Эпоха [97/100] Батч [10000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6929 G_loss: 1.4184
# Эпоха [97/100] Батч [10500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6917 G_loss: 1.4305
# Эпоха [97/100] Батч [11000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6931 G_loss: 1.4187
# Эпоха [97/100] Батч [11500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6929 G_loss: 1.4234
# Эпоха [97/100] Батч [12000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6933 G_loss: 1.4146
# Эпоха [97/100] Батч [12500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6935 G_loss: 1.4118
# Эпоха [97/100] Батч [13000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6924 G_loss: 1.4224
# Эпоха [97/100] Батч [13500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6915 G_loss: 1.4261
# Эпоха [97/100] Батч [14000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6919 G_loss: 1.4239
# Эпоха [97/100] Батч [14500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6931 G_loss: 1.4190
# Эпоха [97/100] Батч [15000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6926 G_loss: 1.4201
# Эпоха [97/100] Батч [15500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6934 G_loss: 1.4243
# Эпоха [97/100] Батч [16000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6925 G_loss: 1.4219
# Эпоха [97/100] Батч [16500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6920 G_loss: 1.4191
# Эпоха [97/100] Батч [17000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6926 G_loss: 1.4161
# Эпоха [97/100] Обучение--- D_lit_loss: 0.6931 D_conv_loss: 0.6928 G_loss: 1.4216 cycle_loss: 0.0046 identity_loss: 0.0041
# Эпоха [97/100] Валидация --- Val_D_lit_loss: 0.6931 Val_D_conv_loss: 0.6925 Val_G_loss: 1.4301 Val_cycle_loss: 0.0052 Val_identity_loss: 0.0056
# Модели перезаписаны в version_4 на 97 эпохе
# Эпоха [98/100] Батч [0/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6926 G_loss: 1.4151
# Эпоха [98/100] Батч [500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6921 G_loss: 1.4340
# Эпоха [98/100] Батч [1000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6936 G_loss: 1.4260
# Эпоха [98/100] Батч [1500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6931 G_loss: 1.4277
# Эпоха [98/100] Батч [2000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6938 G_loss: 1.4205
# Эпоха [98/100] Батч [2500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6931 G_loss: 1.4274
# Эпоха [98/100] Батч [3000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6919 G_loss: 1.4294
# Эпоха [98/100] Батч [3500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6916 G_loss: 1.4222
# Эпоха [98/100] Батч [4000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6921 G_loss: 1.4208
# Эпоха [98/100] Батч [4500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6932 G_loss: 1.4371
# Эпоха [98/100] Батч [5000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6929 G_loss: 1.4163
# Эпоха [98/100] Батч [5500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6932 G_loss: 1.4203
# Эпоха [98/100] Батч [6000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6924 G_loss: 1.4138
# Эпоха [98/100] Батч [6500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6914 G_loss: 1.4184
# Эпоха [98/100] Батч [7000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6928 G_loss: 1.4164
# Эпоха [98/100] Батч [7500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6925 G_loss: 1.4228
# Эпоха [98/100] Батч [8000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6930 G_loss: 1.4143
# Эпоха [98/100] Батч [8500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6931 G_loss: 1.4186
# Эпоха [98/100] Батч [9000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6916 G_loss: 1.4248
# Эпоха [98/100] Батч [9500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6923 G_loss: 1.4237
# Эпоха [98/100] Батч [10000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6927 G_loss: 1.4107
# Эпоха [98/100] Батч [10500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6925 G_loss: 1.4350
# Эпоха [98/100] Батч [11000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6925 G_loss: 1.4151
# Эпоха [98/100] Батч [11500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6931 G_loss: 1.4158
# Эпоха [98/100] Батч [12000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6921 G_loss: 1.4304
# Эпоха [98/100] Батч [12500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6910 G_loss: 1.4244
# Эпоха [98/100] Батч [13000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6916 G_loss: 1.4183
# Эпоха [98/100] Батч [13500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6920 G_loss: 1.4191
# Эпоха [98/100] Батч [14000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6924 G_loss: 1.4173
# Эпоха [98/100] Батч [14500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6928 G_loss: 1.4295
# Эпоха [98/100] Батч [15000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6922 G_loss: 1.4219
# Эпоха [98/100] Батч [15500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6928 G_loss: 1.4303
# Эпоха [98/100] Батч [16000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6907 G_loss: 1.4174
# Эпоха [98/100] Батч [16500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6936 G_loss: 1.4316
# Эпоха [98/100] Батч [17000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6934 G_loss: 1.4142
# Эпоха [98/100] Обучение--- D_lit_loss: 0.6931 D_conv_loss: 0.6926 G_loss: 1.4219 cycle_loss: 0.0046 identity_loss: 0.0041
# Эпоха [98/100] Валидация --- Val_D_lit_loss: 0.6931 Val_D_conv_loss: 0.6925 Val_G_loss: 1.4317 Val_cycle_loss: 0.0054 Val_identity_loss: 0.0058
# Модели перезаписаны в version_4 на 98 эпохе
# Эпоха [99/100] Батч [0/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6940 G_loss: 1.4297
# Эпоха [99/100] Батч [500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6929 G_loss: 1.4123
# Эпоха [99/100] Батч [1000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6923 G_loss: 1.4078
# Эпоха [99/100] Батч [1500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6927 G_loss: 1.4168
# Эпоха [99/100] Батч [2000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6926 G_loss: 1.4092
# Эпоха [99/100] Батч [2500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6935 G_loss: 1.4321
# Эпоха [99/100] Батч [3000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6924 G_loss: 1.4127
# Эпоха [99/100] Батч [3500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6928 G_loss: 1.4252
# Эпоха [99/100] Батч [4000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6918 G_loss: 1.4286
# Эпоха [99/100] Батч [4500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6917 G_loss: 1.4134
# Эпоха [99/100] Батч [5000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6917 G_loss: 1.4220
# Эпоха [99/100] Батч [5500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6927 G_loss: 1.4249
# Эпоха [99/100] Батч [6000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6921 G_loss: 1.4123
# Эпоха [99/100] Батч [6500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6924 G_loss: 1.4283
# Эпоха [99/100] Батч [7000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6932 G_loss: 1.4161
# Эпоха [99/100] Батч [7500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6928 G_loss: 1.4376
# Эпоха [99/100] Батч [8000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6922 G_loss: 1.4222
# Эпоха [99/100] Батч [8500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6927 G_loss: 1.4189
# Эпоха [99/100] Батч [9000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6930 G_loss: 1.4194
# Эпоха [99/100] Батч [9500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6924 G_loss: 1.4187
# Эпоха [99/100] Батч [10000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6927 G_loss: 1.4263
# Эпоха [99/100] Батч [10500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6920 G_loss: 1.4275
# Эпоха [99/100] Батч [11000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6942 G_loss: 1.4139
# Эпоха [99/100] Батч [11500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6920 G_loss: 1.4205
# Эпоха [99/100] Батч [12000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6930 G_loss: 1.4459
# Эпоха [99/100] Батч [12500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6921 G_loss: 1.4316
# Эпоха [99/100] Батч [13000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6922 G_loss: 1.4250
# Эпоха [99/100] Батч [13500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6924 G_loss: 1.4194
# Эпоха [99/100] Батч [14000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6913 G_loss: 1.4181
# Эпоха [99/100] Батч [14500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6928 G_loss: 1.4205
# Эпоха [99/100] Батч [15000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6924 G_loss: 1.4149
# Эпоха [99/100] Батч [15500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6920 G_loss: 1.4161
# Эпоха [99/100] Батч [16000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6923 G_loss: 1.4149
# Эпоха [99/100] Батч [16500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6936 G_loss: 1.4204
# Эпоха [99/100] Батч [17000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6929 G_loss: 1.4220
# Эпоха [99/100] Обучение--- D_lit_loss: 0.6931 D_conv_loss: 0.6925 G_loss: 1.4222 cycle_loss: 0.0046 identity_loss: 0.0042
# Эпоха [99/100] Валидация --- Val_D_lit_loss: 0.6931 Val_D_conv_loss: 0.6923 Val_G_loss: 1.4305 Val_cycle_loss: 0.0051 Val_identity_loss: 0.0056
# Модели перезаписаны в version_4 на 99 эпохе
# Эпоха [100/100] Батч [0/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6923 G_loss: 1.4080
# Эпоха [100/100] Батч [500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6930 G_loss: 1.4174
# Эпоха [100/100] Батч [1000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6933 G_loss: 1.4175
# Эпоха [100/100] Батч [1500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6938 G_loss: 1.4207
# Эпоха [100/100] Батч [2000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6921 G_loss: 1.4191
# Эпоха [100/100] Батч [2500/17229] D_lit_loss: 0.6930 D_conv_loss: 0.6917 G_loss: 1.4331
# Эпоха [100/100] Батч [3000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6914 G_loss: 1.4254
# Эпоха [100/100] Батч [3500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6924 G_loss: 1.4417
# Эпоха [100/100] Батч [4000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6919 G_loss: 1.4242
# Эпоха [100/100] Батч [4500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6920 G_loss: 1.4263
# Эпоха [100/100] Батч [5000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6939 G_loss: 1.4166
# Эпоха [100/100] Батч [5500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6919 G_loss: 1.4291
# Эпоха [100/100] Батч [6000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6923 G_loss: 1.4149
# Эпоха [100/100] Батч [6500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6911 G_loss: 1.4156
# Эпоха [100/100] Батч [7000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6924 G_loss: 1.4246
# Эпоха [100/100] Батч [7500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6932 G_loss: 1.4212
# Эпоха [100/100] Батч [8000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6927 G_loss: 1.4176
# Эпоха [100/100] Батч [8500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6908 G_loss: 1.4169
# Эпоха [100/100] Батч [9000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6931 G_loss: 1.4414
# Эпоха [100/100] Батч [9500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6940 G_loss: 1.4229
# Эпоха [100/100] Батч [10000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6926 G_loss: 1.4243
# Эпоха [100/100] Батч [10500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6935 G_loss: 1.4261
# Эпоха [100/100] Батч [11000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6905 G_loss: 1.4183
# Эпоха [100/100] Батч [11500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6917 G_loss: 1.4200
# Эпоха [100/100] Батч [12000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6918 G_loss: 1.4248
# Эпоха [100/100] Батч [12500/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6918 G_loss: 1.4261
# Эпоха [100/100] Батч [13000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6927 G_loss: 1.4147
# Эпоха [100/100] Батч [13500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6923 G_loss: 1.4170
# Эпоха [100/100] Батч [14000/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6920 G_loss: 1.4180
# Эпоха [100/100] Батч [14500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6918 G_loss: 1.4331
# Эпоха [100/100] Батч [15000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6919 G_loss: 1.4251
# Эпоха [100/100] Батч [15500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6926 G_loss: 1.4170
# Эпоха [100/100] Батч [16000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6926 G_loss: 1.4162
# Эпоха [100/100] Батч [16500/17229] D_lit_loss: 0.6932 D_conv_loss: 0.6919 G_loss: 1.4137
# Эпоха [100/100] Батч [17000/17229] D_lit_loss: 0.6931 D_conv_loss: 0.6916 G_loss: 1.4186
# Эпоха [100/100] Обучение--- D_lit_loss: 0.6931 D_conv_loss: 0.6924 G_loss: 1.4223 cycle_loss: 0.0046 identity_loss: 0.0042
# Эпоха [100/100] Валидация --- Val_D_lit_loss: 0.6931 Val_D_conv_loss: 0.6922 Val_G_loss: 1.4304 Val_cycle_loss: 0.0051 Val_identity_loss: 0.0056
# Debugging plot_losses:
# Length epochs_range: 100
# Length history['D_lit_train']: 100
# Length history['D_conv_train']: 100
# Length history['G_train']: 100
# Length history['cycle_train']: 100
# Length history['identity_train']: 100
# Length history['D_lit_val']: 100
# Length history['D_conv_val']: 100
# Length history['G_val']: 100
# Length history['cycle_val']: 100
# Length history['identity_val']: 100
# Модели перезаписаны в version_4 на 100 эпохе
# Обучение завершено!

# %% [markdown]
# # Ручные тесты

# %%
path = 'navec_hudlit_v1_12B_500K_300d_100q.tar'
navec = Navec.load(path)

embeddings = list()
for word in navec.vocab.words:
        embeddings.append(navec[word])
embeddings = np.array(embeddings)

target_dim = 10
max_vector_length = 40
pca = PCA(n_components=target_dim)
reduced_embeddings = pca.fit_transform(embeddings)

reduced_navec = {word: np.array(reduced_embeddings[i], dtype=np.float16) for i, word in enumerate(navec.vocab.words)}

punkt_vectors = {
    ".": np.array([0.0] * (target_dim - 1) + [1.0], dtype=np.float16),
    "!": np.array([0.0] * (target_dim - 1) + [0.9], dtype=np.float16),
    "?": np.array([0.0] * (target_dim - 1) + [0.8], dtype=np.float16),
    ",": np.array([0.0] * (target_dim - 1) + [0.5], dtype=np.float16),
    ":": np.array([0.0] * (target_dim - 1) + [0.6], dtype=np.float16),
    "–": np.array([0.0] * (target_dim - 1) + [0.4], dtype=np.float16),
    "-": np.array([0.0] * (target_dim - 1) + [0.4], dtype=np.float16),
    "—": np.array([0.0] * (target_dim - 1) + [0.4], dtype=np.float16),
    "«": np.array([0.0] * (target_dim - 1) + [0.2], dtype=np.float16),
    "»": np.array([0.0] * (target_dim - 1) + [0.3], dtype=np.float16),
}

combined_vectors = {**reduced_navec, **punkt_vectors} 
combined_items = list(combined_vectors.keys()) 
combined_embeddings = np.array(list(combined_vectors.values()))

# %%
def text_to_vec(text):
    sentence = text.strip()
    sentence = sentence.strip()
    sentence = re.sub("[^а-яА-Я–-—,.!?:«» ]", "", sentence)
    start_removed = 0
    while len(sentence) > 0 and sentence[0] in "–-—,.!?:«» ":
        start_removed += 1
    sentence = sentence[start_removed:]
    tokens = word_tokenize(sentence)
    tokens = tokens[:max_vector_length]
    padding_for = max_vector_length - len(tokens)
    vector = [np.zeros(target_dim)] * padding_for
    for word in tokens:
        try:
            vector.append(reduced_navec[word])
        except KeyError:
            try:
                vector.append(punkt_vectors[word])
            except KeyError:
                vector.append(reduced_navec["<unk>"])
    vector = np.array(vector, dtype=np.float16).reshape(max_vector_length * target_dim)
    return torch.tensor(vector, dtype=torch.float32).unsqueeze(0).to(device)


def vec_to_text(vector):
    vector_2d = vector.reshape(max_vector_length, target_dim)

    tokens = []
    combined_vectors = {**reduced_navec, **punkt_vectors}
    combined_items = list(combined_vectors.keys())
    combined_embeddings = np.array(list(combined_vectors.values()))

    for vec in vector_2d:
        if isinstance(vec, torch.Tensor):
            vec_np = vec.cpu().numpy()
        else: 
            vec_np = vec

        if np.all(vec_np == 0):
            continue

        if isinstance(vec, torch.Tensor):
            distances = scipy.spatial.distance.cdist(vec.reshape(1, -1).cpu().numpy(), combined_embeddings, metric='euclidean')[0] 
        else: 
            distances = scipy.spatial.distance.cdist(vec.reshape(1, -1), combined_embeddings, metric='euclidean')[0]
        closest_token_index = np.argmin(distances)
        closest_token = combined_items[closest_token_index]
        tokens.append(closest_token)

    reconstructed_text_parts = []
    for token in tokens:
        if token in punkt_vectors:
            reconstructed_text_parts.append(token)
        else:
            reconstructed_text_parts.append(" " + token)

    reconstructed_text = "".join(reconstructed_text_parts).strip()
    return reconstructed_text

# %%
v3_generator_LitToConv = Generator(vector_dimension, vector_dimension).to(device)
v3_generator_ConvToLit = Generator(vector_dimension, vector_dimension).to(device)
v3_discriminator_Literary = Discriminator(vector_dimension, lstm_hidden_dim_discriminator, lstm_num_layers_discriminator, leaky_relu_negative_slope, discriminator_layer_size_hidden, discriminator_dropout_rate).to(device)
v3_discriminator_Conversational = Discriminator(vector_dimension, lstm_hidden_dim_discriminator, lstm_num_layers_discriminator, leaky_relu_negative_slope, discriminator_layer_size_hidden, discriminator_dropout_rate).to(device)

# %%
v3_generator_LitToConv.load_state_dict(torch.load(os.path.join(output_dir, 'generator_lit_to_conv.pth'), map_location=device))
v3_generator_ConvToLit.load_state_dict(torch.load(os.path.join(output_dir, 'generator_conv_to_lit.pth'), map_location=device))
v3_generator_LitToConv.eval()
v3_generator_ConvToLit.eval()
# Out:
# Generator(
#   (lstm): LSTM(400, 400, num_layers=3, batch_first=True)
#   (linear_out): Linear(in_features=400, out_features=400, bias=True)
# )

# %%
lit_text = "У лукоморья дуб зелёный Златая цепь на дубе том И днём и ночью кот учёный Всё ходит по цепи кругом"
lit_vec = text_to_vec(lit_text)

# %%
with torch.no_grad():
    v3_fake_conv = v3_generator_LitToConv(lit_vec)
    v3_fake_conv_to_lit = v3_generator_ConvToLit(v3_fake_conv)

# %%
print(lit_text)
print(vec_to_text(v3_fake_conv))
print(vec_to_text(v3_fake_conv_to_lit))
# Out:
# У лукоморья дуб зелёный Златая цепь на дубе том И днём и ночью кот учёный Всё ходит по цепи кругом
# «««««««««««««««««««« <unk> лукоморья дуб <unk> <unk> цепь на дубе том <unk> <unk> и ночью кот <unk> <unk> ходит по цепи кругом
# «««««««««««««««««««« <unk> лукоморья дуб <unk> <unk> цепь на дубе том <unk> <unk> и ночью кот <unk> <unk> ходит по пленки–
